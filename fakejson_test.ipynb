# %% [markdown]
# This file is for the testing of a fake json files to test the image creation

# %%
import training as training
import reader as read
import procesador as process
import images as im
import random as random

# %% [markdown]
# ### Temporary_json

# %%
TTjets = {
    "Event": {
        "10924": {
            "electron": {
                "0": {
                    "eta": -0.24675194919109344,
                    "phi": 0.0,
                    "pt": 4.807376861572266,
                    "px": 3.2151896953582764,
                    "py": 3.57399320602417,
                    "pz": 1.1983038187026978,
                    "tightID": False,
                    "tightIso": False
                }
            },
            "isMC": 1,
            "jet": {
                "0": {
                    "CSV": 0.0,
                    "eta": 0.15902377665042877,
                    "phi": 0.10640813410282135,
                    "pt": 118.67224884033203,
                    "tightID": True
                },
                "1": {
                    "CSV": 0.0,
                    "eta": 1.2415012121200562,
                    "phi": -2.9924166202545166,
                    "pt": 93.08139038085938,
                    "tightID": True
                },
                "2": {
                    "CSV": 0.0,
                    "eta": 2.0904548168182373,
                    "phi": -3.0853991508483887,
                    "pt": 30.53948974609375,
                    "tightID": True
                }
            },
            "muon": {
                "0": {
                    #"CSV": 0.0,
                    "eta": 0.15902377665042877,
                    "phi": 0.10640813410282135,
                    "pt": 118.67224884033203,
                    "px": 3.2151896953582764,
                    "py": 3.57399320602417,
                    "pz": 1.1983038187026978,
                    "tightID": True,
                    "tightIso": True
                },
                "1": {
                    #"CSV": 0.0,
                    "eta": 1.2415012121200562,
                    "phi": -2.9924166202545166,
                    "pt": 93.08139038085938,
                    "px": 1.2151896953582764,
                    "py": 2.47399320602417,
                    "pz": 2.1343038187026978,
                    "tightID": True,
                    "tightIso": True
                },
                "2": {
                    "CSV": 0.0,
                    "eta": 2.0904548168182373,
                    "phi": -3.0853991508483887,
                    "pt": 30.53948974609375,
                    "px": 2.2151896953582764,
                    "py": 1.78399320602417,
                    "pz": 1.6583038187026978,
                    "tightID": True,
                    "tightIso": True
                }
            },
            
            "lumi": 34,
            "met": 9.485719680786133,
            "met_phi": 0.10640813410282135,
            "njet": 3,
            "numel": 1,
            "nummu": 0,
            "run": 1,
            "sumet": 741.0895385742188,
            "xsec": 784265.1875
        },
        
        "10925": {
            "electron": {
                "0": {
                    "eta": -0.24675194919109344,
                    "phi": 0.0,
                    "pt": 4.807376861572266,
                    "px": 3.2151896953582764,
                    "py": 3.57399320602417,
                    "pz": 1.1983038187026978,
                    "tightID": False,
                    "tightIso": False
                }
            },
            "isMC": 1,
            "jet": {
                "0": {
                    "CSV": 0.0,
                    "eta": 0.15902377665042877,
                    "phi": 0.10640813410282135,
                    "pt": 118.67224884033203,
                    "tightID": True
                },
                "1": {
                    "CSV": 0.0,
                    "eta": 1.2415012121200562,
                    "phi": -2.9924166202545166,
                    "pt": 93.08139038085938,
                    "tightID": True
                },
                "2": {
                    "CSV": 0.0,
                    "eta": 2.0904548168182373,
                    "phi": -3.0853991508483887,
                    "pt": 30.53948974609375,
                    "tightID": True
                }
            },
            "muon": {
                "0": {
                    #"CSV": 0.0,
                    "eta": 0.15902377665042877,
                    "phi": 0.10640813410282135,
                    "pt": 118.67224884033203,
                    "px": 3.2151896953582764,
                    "py": 3.57399320602417,
                    "pz": 1.1983038187026978,
                    "tightID": True,
                    "tightIso": True
                },
                "1": {
                    #"CSV": 0.0,
                    "eta": 1.2415012121200562,
                    "phi": -2.9924166202545166,
                    "pt": 93.08139038085938,
                    "px": 1.2151896953582764,
                    "py": 2.47399320602417,
                    "pz": 2.1343038187026978,
                    "tightID": True,
                    "tightIso": True
                },
                "2": {
                    "CSV": 0.0,
                    "eta": 2.0904548168182373,
                    "phi": -3.0853991508483887,
                    "pt": 30.53948974609375,
                    "px": 2.2151896953582764,
                    "py": 1.78399320602417,
                    "pz": 1.6583038187026978,
                    "tightID": True,
                    "tightIso": True
                }
            },
            
            "lumi": 34,
            "met": 9.485719680786133,
            "met_phi": 0.10640813410282135,
            "njet": 3,
            "numel": 1,
            "nummu": 0,
            "run": 1,
            "sumet": 741.0895385742188,
            "xsec": 784265.1875
        },
        "10926": {
            "electron": {
                "0": {
                    "eta": -0.24675194919109344,
                    "phi": 0.0,
                    "pt": 4.807376861572266,
                    "px": 3.2151896953582764,
                    "py": 3.57399320602417,
                    "pz": 1.1983038187026978,
                    "tightID": False,
                    "tightIso": False
                }
            },
            "isMC": 1,
            "jet": {
                "0": {
                    "CSV": 0.0,
                    "eta": 0.15902377665042877,
                    "phi": 0.10640813410282135,
                    "pt": 118.67224884033203,
                    "tightID": True
                },
                "1": {
                    "CSV": 0.0,
                    "eta": 1.2415012121200562,
                    "phi": -2.9924166202545166,
                    "pt": 93.08139038085938,
                    "tightID": True
                },
                "2": {
                    "CSV": 0.0,
                    "eta": 2.0904548168182373,
                    "phi": -3.0853991508483887,
                    "pt": 30.53948974609375,
                    "tightID": True
                }
            },
            "muon": {
                "0": {
                    #"CSV": 0.0,
                    "eta": 0.15902377665042877,
                    "phi": 0.10640813410282135,
                    "pt": 118.67224884033203,
                    "px": 3.2151896953582764,
                    "py": 3.57399320602417,
                    "pz": 1.1983038187026978,
                    "tightID": True,
                    "tightIso": True
                },
                "1": {
                    #"CSV": 0.0,
                    "eta": 1.2415012121200562,
                    "phi": -2.9924166202545166,
                    "pt": 93.08139038085938,
                    "px": 1.2151896953582764,
                    "py": 2.47399320602417,
                    "pz": 2.1343038187026978,
                    "tightID": True,
                    "tightIso": True
                },
                "2": {
                    "CSV": 0.0,
                    "eta": 2.0904548168182373,
                    "phi": -3.0853991508483887,
                    "pt": 30.53948974609375,
                    "px": 2.2151896953582764,
                    "py": 1.78399320602417,
                    "pz": 1.6583038187026978,
                    "tightID": True,
                    "tightIso": True
                }
            },
            
            "lumi": 34,
            "met": 9.485719680786133,
            "met_phi": 0.10640813410282135,
            "njet": 3,
            "numel": 1,
            "nummu": 0,
            "run": 1,
            "sumet": 741.0895385742188,
            "xsec": 784265.1875
        },
        
        "10927": {
            "electron": {
                "0": {
                    "eta": -0.24675194919109344,
                    "phi": 0.0,
                    "pt": 4.807376861572266,
                    "px": 3.2151896953582764,
                    "py": 3.57399320602417,
                    "pz": 1.1983038187026978,
                    "tightID": False,
                    "tightIso": False
                }
            },
            "isMC": 1,
            "jet": {
                "0": {
                    "CSV": 0.0,
                    "eta": 0.15902377665042877,
                    "phi": 0.10640813410282135,
                    "pt": 118.67224884033203,
                    "tightID": True
                },
                "1": {
                    "CSV": 0.0,
                    "eta": 1.2415012121200562,
                    "phi": -2.9924166202545166,
                    "pt": 93.08139038085938,
                    "tightID": True
                },
                "2": {
                    "CSV": 0.0,
                    "eta": 2.0904548168182373,
                    "phi": -3.0853991508483887,
                    "pt": 30.53948974609375,
                    "tightID": True
                }
            },
            "muon": {
                "0": {
                    #"CSV": 0.0,
                    "eta": 0.15902377665042877,
                    "phi": 0.10640813410282135,
                    "pt": 118.67224884033203,
                    "px": 3.2151896953582764,
                    "py": 3.57399320602417,
                    "pz": 1.1983038187026978,
                    "tightID": True,
                    "tightIso": True
                },
                "1": {
                    #"CSV": 0.0,
                    "eta": 1.2415012121200562,
                    "phi": -2.9924166202545166,
                    "pt": 93.08139038085938,
                    "px": 1.2151896953582764,
                    "py": 2.47399320602417,
                    "pz": 2.1343038187026978,
                    "tightID": True,
                    "tightIso": True
                },
                "2": {
                    "CSV": 0.0,
                    "eta": 2.0904548168182373,
                    "phi": -3.0853991508483887,
                    "pt": 30.53948974609375,
                    "px": 2.2151896953582764,
                    "py": 1.78399320602417,
                    "pz": 1.6583038187026978,
                    "tightID": True,
                    "tightIso": True
                }
            },
            
            "lumi": 34,
            "met": 9.485719680786133,
            "met_phi": 0.10640813410282135,
            "njet": 3,
            "numel": 1,
            "nummu": 0,
            "run": 1,
            "sumet": 741.0895385742188,
            "xsec": 784265.1875
        }
    }
}

# %%
DY = TTjets
Wjets = TTjets

# %%
im.generateAllhistograms(TTjets, DirName = 'TTjets Before Filter', origen = 'TTjets')
im.generateAllhistograms(DY, DirName = 'DY Before Filter', origen = 'DY')
im.generateAllhistograms(Wjets, DirName = 'Wjets Before Filter', origen = 'Wjets')
# Out:
# C:\Users\jeremy yee\Documents\LHC_GRP\clean\Image-Creation\images.py:311: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.hist(variable[magnitude], bins = np.logspace(0, maxPoint, 100), color = c, log = True, label=origen)
# C:\Users\jeremy yee\Documents\LHC_GRP\clean\Image-Creation\images.py:312: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.semilogx()
# C:\Users\jeremy yee\Documents\LHC_GRP\clean\Image-Creation\images.py:339: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.hist(magnitudeSet, bins = np.logspace(0, maxPoint, 100), color = 'b', log = True, label=origen)
# C:\Users\jeremy yee\Documents\LHC_GRP\clean\Image-Creation\images.py:340: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.semilogx()
# TTjets Before Filter histograms created
# DY Before Filter histograms created
# Wjets Before Filter histograms created

# %%
# Draw the events

import images as im

im.generateAllEvents(DY, 'DY', 'json')

im.generateAllEvents(TTjets, 'TTjets', 'json')

im.generateAllEvents(Wjets, 'Wjets', 'json')
# Out:
# 0 out of 4 completed
# 1 out of 4 completed
# 2 out of 4 completed
# 3 out of 4 completed
# All DY events have been created
# 0 out of 4 completed
# 1 out of 4 completed
# 2 out of 4 completed
# 3 out of 4 completed
# All TTjets events have been created
# 0 out of 4 completed
# 1 out of 4 completed
# 2 out of 4 completed
# 3 out of 4 completed
# All Wjets events have been created

# %%
from IPython.display import Image
Image(filename='CreatedImages/DY Images/DY_event_10924.jpg')
