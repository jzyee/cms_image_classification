# %% [markdown]
# #notebook setup

# %%
# !pip install google-auth --upgrade
# !pip install grpcio --upgrade
# Out:
# Requirement already up-to-date: google-auth in /usr/local/lib/python3.6/dist-packages (1.10.0)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (1.12.0)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth) (4.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (4.0.0)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (42.0.2)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth) (0.2.7)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth) (0.4.8)
# Requirement already up-to-date: grpcio in /usr/local/lib/python3.6/dist-packages (1.26.0)
# Requirement already satisfied, skipping upgrade: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio) (1.12.0)

# %%
# !pip install -qq tf-nightly-gpu-2.0-preview
# Out:
#      |████████████████████████████████| 395.5MB 37kB/s
#      |████████████████████████████████| 3.8MB 61.3MB/s
#      |████████████████████████████████| 450kB 57.5MB/s

# %%
import tensorflow as tf
print(tf.__version__)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# 2.0.0-dev20191002
# Found GPU at: /device:GPU:0

# %%
import sys
try:
    import ujson as json
except ImportError:
    try:
        import simplejson as json
    except ImportError:
        import json

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.preprocessing import MinMaxScaler
import pywt
import os
from PIL import Image
# import tensorflow as tf
from glob import glob

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import Model,load_model,Sequential

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout,Flatten, Input
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
def plot_hist(input_history, filename):
  import os

  folder = ['acc', 'loss']

  directory = cwd + '/model_performance/'

  for f in folder:
    if not os.path.exists(directory + f):
      os.makedirs(directory + f)

  # summarize history for accuracy
  # fig, ax = plt.subplots(1,2)
  # plt.subplots_adjust(right=2)

  plt.plot(input_history.history['accuracy'])
  plt.plot(input_history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')

  plt.savefig(cwd+'/model_performance/acc/' + filename + '.jpg')
  plt.show()
  
  # summarize history for loss
  plt.plot(input_history.history['loss'])
  plt.plot(input_history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')

  
  plt.savefig(cwd+'/model_performance/loss/' + filename + '.jpg')

# %% [markdown]
# # Data prep

# %%
# %cd drive/'My Drive/CMS'
# !pwd
# Out:
# /content/drive/My Drive/CMS
# /content/drive/My Drive/CMS

# %%
img_folder = '/filtered_images'
# !ls 'filtered_images'
# Out:
# 0  1  2

# %% [markdown]
# class 0 : DYjets
# class 1 : TTjets
# class 2 : Wjets

# %% [markdown]
# ## Train val size setting

# %%
cwd = os.getcwd()
img_path = cwd + img_folder

train_val_size = 1200

df = {}
data = []
for idx, x in enumerate(os.listdir(img_path)):
  if x.isdigit() and idx < 3:
    for idx2, pic in enumerate(os.listdir(img_path+'/'+str(x))):
      if idx2 < train_val_size:
        data.append((img_path+ '/' + x + '/' + pic , x))

df = pd.DataFrame(data, columns=['filename', 'class'])
df['class'] = df['class'].astype(int)
#shuffle
df = df.sample(frac=1).reset_index(drop=True)

print(df.head())
print(len(df))
df.dtypes
# Out:
#                                             filename  class
# 0  /content/drive/My Drive/CMS/filtered_images/0/...      0
# 1  /content/drive/My Drive/CMS/filtered_images/0/...      0
# 2  /content/drive/My Drive/CMS/filtered_images/0/...      0
# 3  /content/drive/My Drive/CMS/filtered_images/2/...      2
# 4  /content/drive/My Drive/CMS/filtered_images/0/...      0
# 3600
# filename    object
# class        int64
# dtype: object

# %%
from collections import Counter
cnt = Counter(df['class'])
cnt
# Out:
# Counter({0: 1200, 1: 1200, 2: 1200})

# %%
# Split into train and validation sets
train_percentage = .8
val_percentage = 0.1
test_percentage = 0.1

train_length = int(len(df) * train_percentage)
df_train = df[:train_length]

val_length = int(len(df) * val_percentage)
df_val = df[train_length : train_length+val_length]

test_length = int(len(df) * test_percentage)
df_test = df[ train_length + val_length : ]

# shuffle 
df_train = df_train.sample(frac=1).reset_index(drop=True)
df_val = df_val.sample(frac=1).reset_index(drop=True)
df_test = df_test.sample(frac=1).reset_index(drop=True)

df_list = [df_train, df_val, df_test]
for df_part in df_list:
  print(len(df_part))
# Out:
# 2880
# 360
# 360

# %% [markdown]
# #### image parsing

# %%
# Reads an image from a file, decodes it into a tensor, and resizes it
# to a fixed shape.
img_rows, img_cols = 200,200
num_classes = len(set(df['class']))
batch_size = 120

def _parse_function(filename, label):
  image_string = tf.io.read_file(filename)
  image_decoded = tf.image.decode_jpeg(image_string)
  image_resized = tf.image.resize(image_decoded, [img_rows, img_cols])
  image_resized = tf.ensure_shape(image_resized ,shape=(img_rows, img_cols,3))
  label = tf.one_hot(label, num_classes)
  return image_resized, label

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((tf.cast(df_train['filename'].values, tf.string),
                                                    tf.cast(df_train['class'].values, tf.int32) ))
train_dataset = train_dataset.map(_parse_function)
train_dataset = train_dataset.shuffle(5000)
train_dataset = train_dataset.repeat()
train_dataset = train_dataset.batch(batch_size, drop_remainder=True)

# %%
valid_dataset = tf.data.Dataset.from_tensor_slices((tf.cast(df_val['filename'].values, tf.string),
                                                    tf.cast(df_val['class'].values, tf.int32) ))
valid_dataset = valid_dataset.map(_parse_function)
valid_dataset = valid_dataset.shuffle(5000)
valid_dataset = valid_dataset.repeat()
valid_dataset = valid_dataset.batch(batch_size, drop_remainder=True)

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((tf.cast(df_test['filename'].values, tf.string),
                                                    tf.cast(df_test['class'].values, tf.int32) ))
test_dataset = test_dataset.map(_parse_function)
test_dataset = test_dataset.shuffle(5000)
test_dataset = test_dataset.repeat()
test_dataset = test_dataset.batch(batch_size, drop_remainder=True)

# %%
train_dataset
# Out:
# <BatchDataset shapes: ((120, 200, 200, 3), (120, 3)), types: (tf.float32, tf.float32)>

# %% [markdown]
# # VGG16

# %% [markdown]
# ## Entirely frozen

# %%
base_vgg16_0 = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(200, 200, 3),pooling=None)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 5s 0us/step

# %%
# add a global spatial average pooling layer
x = base_vgg16_0.output

x = GlobalAveragePooling2D()(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# and a logits layer -- let's say we have 3 classes
predictions = Dense(3, activation='softmax')(x)

# %%
# this is the model we will train
base_vgg16_model = Model(inputs=base_vgg16_0.input, outputs=predictions)

# %%
for layer in base_vgg16_0.layers:
    print(layer.name)
    layer.trainable = False
# Out:
# input_1
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_pool

# %%
for layer in base_vgg16_model.layers:
    print(layer.name,' Trainable =',layer.trainable)
# Out:
# input_1  Trainable = False
# block1_conv1  Trainable = False
# block1_conv2  Trainable = False
# block1_pool  Trainable = False
# block2_conv1  Trainable = False
# block2_conv2  Trainable = False
# block2_pool  Trainable = False
# block3_conv1  Trainable = False
# block3_conv2  Trainable = False
# block3_conv3  Trainable = False
# block3_pool  Trainable = False
# block4_conv1  Trainable = False
# block4_conv2  Trainable = False
# block4_conv3  Trainable = False
# block4_pool  Trainable = False
# block5_conv1  Trainable = False
# block5_conv2  Trainable = False
# block5_conv3  Trainable = False
# block5_pool  Trainable = False
# global_average_pooling2d  Trainable = True
# dense  Trainable = True
# dropout  Trainable = True
# dense_1  Trainable = True
# dropout_1  Trainable = True
# dense_2  Trainable = True
# dropout_2  Trainable = True
# dense_3  Trainable = True

# %%
opt = tf.keras.optimizers.Adam(lr=0.001)
opt1 = tf.keras.optimizers.RMSprop(lr=1e-4)
# compile the model (should be done *after* setting layers to non-trainable)
base_vgg16_model.compile(optimizer=opt1, loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #### fitting the model

# %%
train_steps = int(len(df_train)/batch_size) #total trains set / batch_size
val_steps = int(len(df_val)/batch_size)

print('train steps:',train_steps)
print('val steps:',val_steps)
epochs = 50

#es = EarlyStopping(monitor='accuracy', mode='max', verbose=1, patience=15)

base_vgg16_model_filepath = 'entirely_frozen_vgg16_rmsprop.h5'
mcp = ModelCheckpoint(base_vgg16_model_filepath, monitor='accuracy', save_best_only=True, mode='max')

### Train the model with validation 
entirely_frozen_vgg16_history = base_vgg16_model.fit( train_dataset, steps_per_epoch = train_steps,
                   epochs = epochs,
                   validation_data = valid_dataset,
                   validation_steps = val_steps,
                   callbacks= [#es, 
                               mcp])
# Out:
# train steps: 24
# val steps: 3
# Train for 24 steps, validate for 3 steps
# Epoch 1/50
# 24/24 [==============================] - 1795s 75s/step - loss: 1.6701 - accuracy: 0.4323 - val_loss: 0.6843 - val_accuracy: 0.6556
# Epoch 2/50
# 24/24 [==============================] - 13s 532ms/step - loss: 1.1086 - accuracy: 0.5660 - val_loss: 0.6302 - val_accuracy: 0.6806
# Epoch 3/50
# 24/24 [==============================] - 13s 557ms/step - loss: 0.9456 - accuracy: 0.6066 - val_loss: 0.5849 - val_accuracy: 0.7167
# Epoch 4/50
# 24/24 [==============================] - 13s 525ms/step - loss: 0.8155 - accuracy: 0.6361 - val_loss: 0.5617 - val_accuracy: 0.7417
# Epoch 5/50
# 24/24 [==============================] - 14s 568ms/step - loss: 0.7668 - accuracy: 0.6576 - val_loss: 0.5628 - val_accuracy: 0.7528
# Epoch 6/50
# 24/24 [==============================] - 13s 561ms/step - loss: 0.7165 - accuracy: 0.6788 - val_loss: 0.5471 - val_accuracy: 0.7667
# Epoch 7/50
# 24/24 [==============================] - 12s 514ms/step - loss: 0.7257 - accuracy: 0.6698 - val_loss: 0.5518 - val_accuracy: 0.7611
# Epoch 8/50
# 24/24 [==============================] - 13s 555ms/step - loss: 0.6843 - accuracy: 0.6823 - val_loss: 0.5411 - val_accuracy: 0.7917
# Epoch 9/50
# 24/24 [==============================] - 13s 523ms/step - loss: 0.6691 - accuracy: 0.6913 - val_loss: 0.5392 - val_accuracy: 0.8000
# Epoch 10/50
# 24/24 [==============================] - 12s 517ms/step - loss: 0.6607 - accuracy: 0.6878 - val_loss: 0.5412 - val_accuracy: 0.7722
# Epoch 11/50
# 24/24 [==============================] - 13s 552ms/step - loss: 0.6379 - accuracy: 0.6983 - val_loss: 0.5463 - val_accuracy: 0.7722
# Epoch 12/50
# 24/24 [==============================] - 13s 553ms/step - loss: 0.6250 - accuracy: 0.7024 - val_loss: 0.5284 - val_accuracy: 0.7944
# %%
plot_hist(entirely_frozen_vgg16_history, 'entirely_frozen_vgg16_rmsprop')

# %% [markdown]
# #### saving the history of the fitting

# %%
with open(cwd + '/trainHistoryDict/entirely_frozen_vgg16_rmsprop_history.p', 'wb') as file_pi:
        pickle.dump(entirely_frozen_vgg16_history.history, file_pi)
print('history saved')
# Out:
# history saved

# %% [markdown]
# ## Few layers unfrozen

# %% [markdown]
# #### loading model

# %%
base_vgg16_1 = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(200, 200, 3),pooling=None)

# %% [markdown]
# #### modifying slightly

# %%
# add a global spatial average pooling layer
x = base_vgg16_1.output

x = GlobalAveragePooling2D()(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# and a logits layer -- let's say we have 3 classes
predictions = Dense(3, activation='softmax')(x)

# %% [markdown]
# #### creating model object

# %%
# this is the model we will train
few_unfrozen_vgg16_model = Model(inputs=base_vgg16_1.input, outputs=predictions)

# %%
for layer in base_vgg16_1.layers:
    print(layer.name)
    layer.trainable = False
# Out:
# input_2
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_pool

# %%
trainable_count = 0
per_layers = 0.2
num_model_layers = len(base_vgg16_1.layers)
starting_layer = int( num_model_layers * (1 - per_layers))
true_per_trained = (num_model_layers - starting_layer) / num_model_layers


print('true percentage of model trainable:', true_per_trained)
# Out:
# true percentage of model trainable: 0.21052631578947367

# %%
set_trainable = False
for idx, layer in enumerate(base_vgg16_1.layers):
    if idx == starting_layer:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
        trainable_count += 1
    else:
        layer.trainable = False

# %%
for layer in few_unfrozen_vgg16_model.layers:
    print(layer.name,layer.trainable)
# Out:
# input_2 False
# block1_conv1 False
# block1_conv2 False
# block1_pool False
# block2_conv1 False
# block2_conv2 False
# block2_pool False
# block3_conv1 False
# block3_conv2 False
# block3_conv3 False
# block3_pool False
# block4_conv1 False
# block4_conv2 False
# block4_conv3 False
# block4_pool False
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_pool True
# global_average_pooling2d_1 True
# dense_4 True
# dropout_3 True
# dense_5 True
# dropout_4 True
# dense_6 True
# dropout_5 True
# dense_7 True

# %%
opt = tf.keras.optimizers.Adam(lr=0.001)
# compile the model (should be done *after* setting layers to non-trainable)
few_unfrozen_vgg16_model.compile(optimizer=opt1, loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #### fitting the model

# %%
train_steps = int(len(df_train)/batch_size) #total trains set / batch_size
val_steps = int(len(df_val)/batch_size)

print('train steps:',train_steps)
print('val steps:',val_steps)

epochs = 50


model_filepath = 'few_unfrozen_vgg16_rmsprop.h5'
mcp = ModelCheckpoint(model_filepath, monitor='accuracy', save_best_only=True, mode='max')

# Train the model with validation 
few_unfrozen_vgg16_history = few_unfrozen_vgg16_model.fit( train_dataset, steps_per_epoch = train_steps,
                   epochs = epochs,
                   validation_data = valid_dataset,
                   validation_steps = val_steps,
                   callbacks=[mcp])
# Out:
# train steps: 24
# val steps: 3
# Train for 24 steps, validate for 3 steps
# Epoch 1/50
# 24/24 [==============================] - 14s 587ms/step - loss: 0.9361 - accuracy: 0.5573 - val_loss: 0.5844 - val_accuracy: 0.7194
# Epoch 2/50
# 24/24 [==============================] - 13s 542ms/step - loss: 0.6499 - accuracy: 0.6997 - val_loss: 0.6161 - val_accuracy: 0.7139
# Epoch 3/50
# 24/24 [==============================] - 14s 584ms/step - loss: 0.6207 - accuracy: 0.7302 - val_loss: 0.4872 - val_accuracy: 0.8139
# Epoch 4/50
# 24/24 [==============================] - 13s 547ms/step - loss: 0.5823 - accuracy: 0.7462 - val_loss: 0.5147 - val_accuracy: 0.7722
# Epoch 5/50
# 24/24 [==============================] - 13s 531ms/step - loss: 0.1189 - accuracy: 0.9479 - val_loss: 1.6621 - val_accuracy: 0.7833
# Epoch 46/50
# 24/24 [==============================] - 13s 532ms/step - loss: 0.1413 - accuracy: 0.9476 - val_loss: 1.4064 - val_accuracy: 0.7444
# Epoch 47/50
# 24/24 [==============================] - 14s 576ms/step - loss: 0.0925 - accuracy: 0.9576 - val_loss: 1.6445 - val_accuracy: 0.7778
# Epoch 48/50
# 24/24 [==============================] - 13s 535ms/step - loss: 0.2033 - accuracy: 0.9490 - val_loss: 0.9749 - val_accuracy: 0.7444
# Epoch 49/50
# 24/24 [==============================] - 14s 578ms/step - loss: 0.0683 - accuracy: 0.9736 - val_loss: 1.6555 - val_accuracy: 0.7417
# Epoch 50/50
# 24/24 [==============================] - 13s 533ms/step - loss: 0.0840 - accuracy: 0.9646 - val_loss: 2.1027 - val_accuracy: 0.7750

# %% [markdown]
# #### testing the model

# %%
test_steps = int(len(df_test)/batch_size)

metrics = few_unfrozen_vgg16_model.evaluate(test_dataset,
                   steps = test_steps)
print("model accuracy:",metrics[1])
# Out:
# 3/3 [==============================] - 1s 461ms/step - loss: 2.8296 - accuracy: 0.7611
# model accuracy: 0.76111114

# %% [markdown]
# #### plotting training

# %%
plot_hist(few_unfrozen_vgg16_history, 'few_unfrozen_vgg16_rmsprop')

# %% [markdown]
# #### saving the history of the fitting

# %%
with open(cwd + '/trainHistoryDict/few_unfrozen_vgg16_rmsprop_history.p', 'wb') as file_pi:
        pickle.dump(few_unfrozen_vgg16_history.history, file_pi)
print('history saved')
# Out:
# history saved

# %% [markdown]
# ## Many layers unfrozen

# %% [markdown]
# #### loading model

# %%
base_vgg16_2 = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(200, 200, 3),pooling=None)

# %% [markdown]
# #### modifying slightly

# %%
# add a global spatial average pooling layer
x = base_vgg16_2.output

x = GlobalAveragePooling2D()(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# and a logits layer -- let's say we have 3 classes
predictions = Dense(3, activation='softmax')(x)

# %% [markdown]
# #### creating model object

# %%
# this is the model we will train
many_unfrozen_vgg16_model = Model(inputs=base_vgg16_2.input, outputs=predictions)

# %%
for layer in base_vgg16_2.layers:
    print(layer.name)
    layer.trainable = False
# Out:
# input_3
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_pool

# %%
trainable_count = 0
per_layers = 0.7
num_model_layers = len(base_vgg16_2.layers)
starting_layer = int( num_model_layers * (1 - per_layers))
true_per_trained = (num_model_layers - starting_layer) / num_model_layers


print('true percentage of model trainable:', true_per_trained)
# Out:
# true percentage of model trainable: 0.7368421052631579

# %%
set_trainable = False
for idx, layer in enumerate(base_vgg16_2.layers):
    if idx == starting_layer:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
        trainable_count += 1
    else:
        layer.trainable = False

# %%
for layer in many_unfrozen_vgg16_model.layers:
    print(layer.name,layer.trainable)
# Out:
# input_3 False
# block1_conv1 False
# block1_conv2 False
# block1_pool False
# block2_conv1 False
# block2_conv2 True
# block2_pool True
# block3_conv1 True
# block3_conv2 True
# block3_conv3 True
# block3_pool True
# block4_conv1 True
# block4_conv2 True
# block4_conv3 True
# block4_pool True
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_pool True
# global_average_pooling2d_2 True
# dense_8 True
# dropout_6 True
# dense_9 True
# dropout_7 True
# dense_10 True
# dropout_8 True
# dense_11 True

# %%
opt = tf.keras.optimizers.Adam(lr=0.001)
# compile the model (should be done *after* setting layers to non-trainable)
many_unfrozen_vgg16_model.compile(optimizer=opt1, loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #### fitting the model

# %%
train_steps = int(len(df_train)/batch_size) #total trains set / batch_size
val_steps = int(len(df_val)/batch_size)

print('train steps:',train_steps)
print('val steps:',val_steps)

epochs = 50


model_filepath = 'many_unfrozen_vgg16_rmsprop.h5'
mcp = ModelCheckpoint(model_filepath, monitor='accuracy', save_best_only=True, mode='max')

# Train the model with validation 
many_unfrozen_vgg16_history = many_unfrozen_vgg16_model.fit( train_dataset, steps_per_epoch = train_steps,
                   epochs = epochs,
                   validation_data = valid_dataset,
                   validation_steps = val_steps,
                   callbacks=[mcp])
# Out:
# train steps: 24
# val steps: 3
# Train for 24 steps, validate for 3 steps
# Epoch 1/50
# 24/24 [==============================] - 21s 891ms/step - loss: 1.2984 - accuracy: 0.3455 - val_loss: 1.0931 - val_accuracy: 0.4306
# Epoch 2/50
# 24/24 [==============================] - 20s 831ms/step - loss: 1.1410 - accuracy: 0.3535 - val_loss: 1.0798 - val_accuracy: 0.3250
# Epoch 3/50
# 24/24 [==============================] - 18s 758ms/step - loss: 1.1975 - accuracy: 0.3503 - val_loss: 1.0572 - val_accuracy: 0.3417
# Epoch 4/50
# 24/24 [==============================] - 18s 754ms/step - loss: 1.1010 - accuracy: 0.3493 - val_loss: 1.0971 - val_accuracy: 0.3694
# Epoch 5/50
# 24/24 [==============================] - 18s 760ms/step - loss: 1.0962 - accuracy: 0.3382 - val_loss: 1.0974 - val_accuracy: 0.3083
# Epoch 6/50
# 24/24 [==============================] - 20s 835ms/step - loss: 1.0871 - accuracy: 0.3740 - val_loss: 1.0988 - val_accuracy: 0.3472
# Epoch 7/50
# 24/24 [==============================] - 18s 763ms/step - loss: 1.1469 - accuracy: 0.3535 - val_loss: 1.0984 - val_accuracy: 0.3417
# Epoch 8/50
# 24/24 [==============================] - 18s 762ms/step - loss: 1.0986 - accuracy: 0.3358 - val_loss: 1.0984 - val_accuracy: 0.3417
# Epoch 9/50
# 24/24 [==============================] - 18s 759ms/step - loss: 1.0984 - accuracy: 0.3378 - val_loss: 1.0770 - val_accuracy: 0.3500
# Epoch 10/50
# 24/24 [==============================] - 18s 760ms/step - loss: 1.1625 - accuracy: 0.3410 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 11/50
# 24/24 [==============================] - 18s 759ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 12/50
# 24/24 [==============================] - 18s 759ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 13/50
# 24/24 [==============================] - 18s 759ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 14/50
# 24/24 [==============================] - 18s 761ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 15/50
# 24/24 [==============================] - 18s 755ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 16/50
# 24/24 [==============================] - 18s 763ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 17/50
# 24/24 [==============================] - 18s 768ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 18/50
# 24/24 [==============================] - 18s 761ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 19/50
# 24/24 [==============================] - 18s 757ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 20/50
# 24/24 [==============================] - 18s 758ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 21/50
# 24/24 [==============================] - 18s 762ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 22/50
# 24/24 [==============================] - 18s 756ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 23/50
# 24/24 [==============================] - 18s 754ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 24/50
# 24/24 [==============================] - 18s 758ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 25/50
# 24/24 [==============================] - 18s 757ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 26/50
# 24/24 [==============================] - 18s 752ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 27/50
# 24/24 [==============================] - 18s 755ms/step - loss: 1.0987 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 28/50
# 24/24 [==============================] - 18s 755ms/step - loss: 1.0987 - accuracy: 0.3385 - val_loss: 1.0987 - val_accuracy: 0.3417
# Epoch 29/50
# 24/24 [==============================] - 18s 755ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 30/50
# 24/24 [==============================] - 18s 759ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 31/50
# 24/24 [==============================] - 18s 759ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 32/50
# 24/24 [==============================] - 18s 756ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 33/50
# 24/24 [==============================] - 18s 758ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 34/50
# 24/24 [==============================] - 18s 763ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 35/50
# 24/24 [==============================] - 18s 759ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0987 - val_accuracy: 0.3417
# Epoch 36/50
# 24/24 [==============================] - 18s 753ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 37/50
# 24/24 [==============================] - 18s 753ms/step - loss: 1.0987 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 38/50
# 24/24 [==============================] - 18s 757ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0987 - val_accuracy: 0.3417
# Epoch 39/50
# 24/24 [==============================] - 18s 760ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0987 - val_accuracy: 0.3417
# Epoch 40/50
# 24/24 [==============================] - 18s 757ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0987 - val_accuracy: 0.3417
# Epoch 41/50
# 24/24 [==============================] - 18s 754ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 42/50
# 24/24 [==============================] - 18s 761ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 43/50
# 24/24 [==============================] - 18s 761ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 44/50
# 24/24 [==============================] - 18s 756ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 45/50
# 24/24 [==============================] - 18s 762ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 46/50
# 24/24 [==============================] - 18s 758ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 47/50
# 24/24 [==============================] - 18s 755ms/step - loss: 1.0987 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 48/50
# 24/24 [==============================] - 18s 760ms/step - loss: 1.0985 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 49/50
# 24/24 [==============================] - 18s 757ms/step - loss: 1.0985 - accuracy: 0.3385 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 50/50
# 24/24 [==============================] - 18s 763ms/step - loss: 1.0986 - accuracy: 0.3385 - val_loss: 1.0987 - val_accuracy: 0.3417

# %% [markdown]
# #### testing the model

# %%
test_steps = int(len(df_test)/batch_size)

metrics = many_unfrozen_vgg16_model.evaluate(test_dataset,
                   steps = test_steps)
print("model accuracy:",metrics[1])
# Out:
# 3/3 [==============================] - 1s 467ms/step - loss: 1.0997 - accuracy: 0.2833
# model accuracy: 0.28333333

# %% [markdown]
# #### plotting training

# %%
plot_hist(many_unfrozen_vgg16_history, 'many_unfrozen_vgg16_rmsprop')

# %% [markdown]
# #### saving the history of the fitting

# %%
with open(cwd + '/trainHistoryDict/many_unfrozen_vgg16_rmsprop_history.p', 'wb') as file_pi:
        pickle.dump(many_unfrozen_vgg16_history.history, file_pi)
print('history saved')
# Out:
# history saved

# %% [markdown]
# ## entirely unfrozen

# %%
input_shapes = (200, 200, 3)
base_vgg16_3 = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=input_shapes,pooling=None)

# %% [markdown]
# #### modifying slightly

# %%
# add a global spatial average pooling layer
x = base_vgg16_3.output

x = GlobalAveragePooling2D()(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# and a logits layer -- let's say we have 3 classes
predictions = Dense(3, activation='softmax')(x)

# %% [markdown]
# #### creating model object

# %%
# this is the model we will train
unfrozen_vgg16_model = Model(inputs=base_vgg16_3.input, outputs=predictions)

# %%
for layer in unfrozen_vgg16_model.layers:
    print(layer.name)
    layer.trainable = True
# Out:
# input_4
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_pool
# global_average_pooling2d_3
# dense_12
# dropout_9
# dense_13
# dropout_10
# dense_14
# dropout_11
# dense_15

# %%
for layer in unfrozen_vgg16_model.layers:
    print(layer.name,' Trainable =',layer.trainable)
# Out:
# input_4  Trainable = True
# block1_conv1  Trainable = True
# block1_conv2  Trainable = True
# block1_pool  Trainable = True
# block2_conv1  Trainable = True
# block2_conv2  Trainable = True
# block2_pool  Trainable = True
# block3_conv1  Trainable = True
# block3_conv2  Trainable = True
# block3_conv3  Trainable = True
# block3_pool  Trainable = True
# block4_conv1  Trainable = True
# block4_conv2  Trainable = True
# block4_conv3  Trainable = True
# block4_pool  Trainable = True
# block5_conv1  Trainable = True
# block5_conv2  Trainable = True
# block5_conv3  Trainable = True
# block5_pool  Trainable = True
# global_average_pooling2d_3  Trainable = True
# dense_12  Trainable = True
# dropout_9  Trainable = True
# dense_13  Trainable = True
# dropout_10  Trainable = True
# dense_14  Trainable = True
# dropout_11  Trainable = True
# dense_15  Trainable = True

# %%
unfrozen_vgg16_model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 200, 200, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 200, 200, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 200, 200, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 100, 100, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 100, 100, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 100, 100, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 50, 50, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 50, 50, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 25, 25, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 25, 25, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 15,504,195
# Trainable params: 15,504,195
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### setting the optimizer

# %%
opt = tf.keras.optimizers.Adam(lr=0.001)
opt1 = tf.keras.optimizers.RMSprop(lr=1e-4)
# compile the model (should be done *after* setting layers to non-trainable)
unfrozen_vgg16_model.compile(optimizer=opt1, loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #### fitting the model

# %%
train_steps = int(len(df_train)/batch_size) #total trains set / batch_size
val_steps = int(len(df_val)/batch_size)

print('train steps:',train_steps)
print('val steps:',val_steps)

epochs = 50


model_filepath = 'unfrozen_vgg16_rmsprop.h5'
mcp = ModelCheckpoint(model_filepath, monitor='accuracy', save_best_only=True, mode='max')

# Train the model with validation 
unfrozen_vgg16_history = unfrozen_vgg16_model.fit( train_dataset, steps_per_epoch = train_steps,
                   epochs = epochs,
                   validation_data = valid_dataset,
                   validation_steps = val_steps,
                   callbacks=[mcp])
# Out:
# train steps: 24
# val steps: 3
# Train for 24 steps, validate for 3 steps
# Epoch 1/50
# 24/24 [==============================] - 26s 1s/step - loss: 1.2218 - accuracy: 0.3514 - val_loss: 1.0947 - val_accuracy: 0.3639
# Epoch 2/50
# 24/24 [==============================] - 24s 1s/step - loss: 1.3049 - accuracy: 0.3872 - val_loss: 1.0501 - val_accuracy: 0.5139
# Epoch 3/50
# 24/24 [==============================] - 24s 1s/step - loss: 1.0368 - accuracy: 0.5201 - val_loss: 0.6430 - val_accuracy: 0.6389
# Epoch 4/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.8755 - accuracy: 0.5545 - val_loss: 0.6385 - val_accuracy: 0.6306
# Epoch 5/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.7381 - accuracy: 0.6080 - val_loss: 0.5514 - val_accuracy: 0.7778
# Epoch 6/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.7769 - accuracy: 0.6299 - val_loss: 0.5558 - val_accuracy: 0.7444
# Epoch 7/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.6368 - accuracy: 0.7014 - val_loss: 0.6805 - val_accuracy: 0.6139
# Epoch 8/50
# 24/24 [==============================] - 23s 954ms/step - loss: 0.6590 - accuracy: 0.7010 - val_loss: 0.5910 - val_accuracy: 0.7944
# Epoch 9/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.5861 - accuracy: 0.7337 - val_loss: 0.4730 - val_accuracy: 0.8028
# Epoch 10/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.5914 - accuracy: 0.7500 - val_loss: 0.5392 - val_accuracy: 0.7500
# Epoch 11/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.5640 - accuracy: 0.7556 - val_loss: 0.4776 - val_accuracy: 0.8028
# Epoch 12/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.5316 - accuracy: 0.7708 - val_loss: 0.4773 - val_accuracy: 0.8139
# Epoch 13/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.5085 - accuracy: 0.7715 - val_loss: 0.4895 - val_accuracy: 0.8056
# Epoch 14/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.5058 - accuracy: 0.7816 - val_loss: 0.4387 - val_accuracy: 0.8139
# Epoch 15/50
# 24/24 [==============================] - 23s 959ms/step - loss: 0.5141 - accuracy: 0.7806 - val_loss: 0.4630 - val_accuracy: 0.7889
# Epoch 16/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.4498 - accuracy: 0.8038 - val_loss: 0.4905 - val_accuracy: 0.8000
# Epoch 17/50
# 24/24 [==============================] - 23s 956ms/step - loss: 0.4613 - accuracy: 0.7990 - val_loss: 0.4646 - val_accuracy: 0.8167
# Epoch 18/50
# 24/24 [==============================] - 23s 956ms/step - loss: 0.4516 - accuracy: 0.8017 - val_loss: 0.4870 - val_accuracy: 0.8083
# Epoch 19/50
# 24/24 [==============================] - 23s 951ms/step - loss: 0.4466 - accuracy: 0.7958 - val_loss: 0.4614 - val_accuracy: 0.8000
# Epoch 20/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.4068 - accuracy: 0.8201 - val_loss: 0.4710 - val_accuracy: 0.8028
# Epoch 21/50
# 24/24 [==============================] - 23s 956ms/step - loss: 0.4109 - accuracy: 0.8125 - val_loss: 0.4679 - val_accuracy: 0.7889
# Epoch 22/50
# 24/24 [==============================] - 23s 957ms/step - loss: 0.4251 - accuracy: 0.8087 - val_loss: 0.4806 - val_accuracy: 0.8083
# Epoch 23/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.3763 - accuracy: 0.8288 - val_loss: 0.4856 - val_accuracy: 0.7944
# Epoch 24/50
# 24/24 [==============================] - 23s 954ms/step - loss: 0.3655 - accuracy: 0.8260 - val_loss: 0.5106 - val_accuracy: 0.7806
# Epoch 25/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.3523 - accuracy: 0.8330 - val_loss: 0.5845 - val_accuracy: 0.7972
# Epoch 26/50
# 24/24 [==============================] - 23s 954ms/step - loss: 0.4232 - accuracy: 0.8118 - val_loss: 0.4958 - val_accuracy: 0.7833
# Epoch 27/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.3178 - accuracy: 0.8490 - val_loss: 0.5922 - val_accuracy: 0.7944
# Epoch 28/50
# 24/24 [==============================] - 23s 955ms/step - loss: 0.3094 - accuracy: 0.8476 - val_loss: 0.6414 - val_accuracy: 0.7917
# Epoch 29/50
# 24/24 [==============================] - 23s 954ms/step - loss: 0.3439 - accuracy: 0.8389 - val_loss: 0.5157 - val_accuracy: 0.8167
# Epoch 30/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.2829 - accuracy: 0.8569 - val_loss: 1.2277 - val_accuracy: 0.7583
# Epoch 31/50
# 24/24 [==============================] - 23s 952ms/step - loss: 0.3619 - accuracy: 0.8479 - val_loss: 0.5352 - val_accuracy: 0.8028
# Epoch 32/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.2662 - accuracy: 0.8729 - val_loss: 0.7099 - val_accuracy: 0.7944
# Epoch 33/50
# 24/24 [==============================] - 23s 953ms/step - loss: 0.3068 - accuracy: 0.8503 - val_loss: 0.7083 - val_accuracy: 0.7778
# Epoch 34/50
# 24/24 [==============================] - 23s 957ms/step - loss: 0.2790 - accuracy: 0.8726 - val_loss: 0.5759 - val_accuracy: 0.8000
# Epoch 35/50
# 24/24 [==============================] - 23s 948ms/step - loss: 0.2899 - accuracy: 0.8674 - val_loss: 0.8265 - val_accuracy: 0.8028
# Epoch 36/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.2481 - accuracy: 0.8753 - val_loss: 0.6999 - val_accuracy: 0.8139
# Epoch 37/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.2596 - accuracy: 0.8792 - val_loss: 0.8576 - val_accuracy: 0.7972
# Epoch 38/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.2419 - accuracy: 0.8892 - val_loss: 0.8168 - val_accuracy: 0.7722
# Epoch 39/50
# 24/24 [==============================] - 23s 963ms/step - loss: 0.2351 - accuracy: 0.8889 - val_loss: 1.9064 - val_accuracy: 0.6750
# Epoch 40/50
# 24/24 [==============================] - 23s 966ms/step - loss: 0.3361 - accuracy: 0.8618 - val_loss: 0.7042 - val_accuracy: 0.8028
# Epoch 41/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.2199 - accuracy: 0.8986 - val_loss: 0.8321 - val_accuracy: 0.8000
# Epoch 42/50
# 24/24 [==============================] - 23s 954ms/step - loss: 0.2256 - accuracy: 0.8972 - val_loss: 0.7559 - val_accuracy: 0.7583
# Epoch 43/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.1876 - accuracy: 0.9184 - val_loss: 1.8501 - val_accuracy: 0.6944
# Epoch 44/50
# 24/24 [==============================] - 23s 951ms/step - loss: 0.2509 - accuracy: 0.8976 - val_loss: 0.9536 - val_accuracy: 0.7694
# Epoch 45/50
# 24/24 [==============================] - 23s 952ms/step - loss: 0.2382 - accuracy: 0.9003 - val_loss: 0.7919 - val_accuracy: 0.8000
# Epoch 46/50
# 24/24 [==============================] - 23s 955ms/step - loss: 0.1718 - accuracy: 0.9142 - val_loss: 1.0977 - val_accuracy: 0.7917
# Epoch 47/50
# 24/24 [==============================] - 23s 950ms/step - loss: 0.2528 - accuracy: 0.9035 - val_loss: 0.8341 - val_accuracy: 0.7944
# Epoch 48/50
# 24/24 [==============================] - 23s 951ms/step - loss: 0.1994 - accuracy: 0.9135 - val_loss: 0.6228 - val_accuracy: 0.7611
# Epoch 49/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.1699 - accuracy: 0.9229 - val_loss: 1.0727 - val_accuracy: 0.8000
# Epoch 50/50
# 24/24 [==============================] - 23s 952ms/step - loss: 0.1692 - accuracy: 0.9222 - val_loss: 1.0369 - val_accuracy: 0.7806

# %% [markdown]
# #### testing the model

# %%
test_steps = int(len(df_test)/batch_size)

metrics = unfrozen_vgg16_model.evaluate(test_dataset,
                   steps = test_steps)
print("model accuracy:",metrics[1])
# Out:
# 3/3 [==============================] - 1s 449ms/step - loss: 1.5732 - accuracy: 0.7667
# model accuracy: 0.76666665

# %% [markdown]
# #### plotting training

# %%
plot_hist(unfrozen_vgg16_history, 'unfrozen_vgg16_rmsprop')

# %% [markdown]
# #### saving the history of the fitting

# %%
with open(cwd + '/trainHistoryDict/unfrozen_vgg16_rmsprop_history.p', 'wb') as file_pi:
        pickle.dump(unfrozen_vgg16_history.history, file_pi)
print('history saved')
# Out:
# history saved
