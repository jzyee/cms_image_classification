# %%
import training as training
import reader as read
import procesador as process
import images as im
import random as random

# %%
from os import listdir
listdir('json_files')
# Out:
# ['Dyjets_json.json',
#  'json_readme.txt',
#  'TTjets_json.json',
#  'Wjets_json.json',
#  'ZZjets_json.json']

# %%
import os
import json

cwd = os.getcwd()
json_path = cwd + '/json_files'

with open(json_path + '/Dyjets_json.json') as json_file:
    DYjets = json.load(json_file)

with open(json_path + '/TTjets_json.json') as json_file:
    TTjets = json.load(json_file)

with open(json_path + '/Wjets_json.json') as json_file:
    Wjets = json.load(json_file)

# %%
list(DYjets['Event'].keys())[:5]
# Out:
# ['67242185', '67242186', '67242187', '67242188', '67242190']

# %%
im.generateAllhistograms(DYjets, DirName = 'DYjets Before Filter', origen = 'DY')
im.generateAllhistograms(TTjets, DirName = 'TTjets Before Filter', origen = 'TTjets')
im.generateAllhistograms(Wjets, DirName = 'Wjets Before Filter', origen = 'Wjets')
# Out:
# DYjets Before Filter histograms created
# TTjets Before Filter histograms created
# Wjets Before Filter histograms created

# %%
# Filter the jets, muons and electrons

process.leptonFilter(DYjets, 'muon', minPt = 20, maxPt = False, minEta = False, maxEta = False, tightIDFilter = True, tightIsoFilter = True)
process.leptonFilter(DYjets, 'electron', minPt = 20, maxPt = False, minEta = False, maxEta = False, tightIDFilter = True, tightIsoFilter = True)
process.jetFilter(DYjets, minpt =30, maxpt = False, maxAbsEta = 2.4, jetNumber=False, tightIDFilter = True)

process.leptonFilter(TTjets, 'muon', minPt = 20, maxPt = False, minEta = False, maxEta = False, tightIDFilter = True, tightIsoFilter = True)
process.leptonFilter(TTjets, 'electron', minPt = 20, maxPt = False, minEta = False, maxEta = False, tightIDFilter = True, tightIsoFilter = True)
process.jetFilter(TTjets, minpt =30, maxpt = False, maxAbsEta = 2.4, jetNumber=False, tightIDFilter = True)

process.leptonFilter(Wjets, 'muon', minPt = 20, maxPt = False, minEta = False, maxEta = False, tightIDFilter = True, tightIsoFilter = True)
process.leptonFilter(Wjets, 'electron', minPt = 20, maxPt = False, minEta = False, maxEta = False, tightIDFilter = True, tightIsoFilter = True)
process.jetFilter(Wjets, minpt =30, maxpt = False, maxAbsEta = 2.4, jetNumber=False, tightIDFilter = True)

# %%
im.generateAllhistograms(DYjets, DirName = 'DY After Lepton and Jet Filter', origen = 'DY')
im.generateAllhistograms(TTjets, DirName = 'TTjets After Lepton and Jet Filter', origen = 'TTjets')
im.generateAllhistograms(Wjets, DirName = 'Wjets After Lepton and Jet Filter', origen = 'Wjets')
# Out:
# DY After Lepton and Jet Filter histograms created
# TTjets After Lepton and Jet Filter histograms created
# Wjets After Lepton and Jet Filter histograms created

# %%
process.leptonNumberFilter(DYjets, electronNumber = False, muonNumber = False, leptonNumber = 1)
process.leptonNumberFilter(TTjets, electronNumber = False, muonNumber = False, leptonNumber = 1)
process.leptonNumberFilter(Wjets, electronNumber = False, muonNumber = False, leptonNumber = 1)

# %%
im.generateAllhistograms(DYjets, DirName = 'DY After Event Filter', origen = 'DY')
# 1189 out of 1239 completed
# 1201 out of 1239 completed
# 1214 out of 1239 completed
# 1226 out of 1239 completed
# All TTjets events have been created
# 0 out of 1553 completed
# 15 out of 1553 completed
# 31 out of 1553 completed
# 46 out of 1553 completed
# 62 out of 1553 completed
# 77 out of 1553 completed
# 93 out of 1553 completed
# 108 out of 1553 completed
# 124 out of 1553 completed
# 139 out of 1553 completed
# 155 out of 1553 completed
# 170 out of 1553 completed
# 186 out of 1553 completed
# 201 out of 1553 completed
# 217 out of 1553 completed
# 232 out of 1553 completed
# 248 out of 1553 completed
# 264 out of 1553 completed
# 279 out of 1553 completed
# 295 out of 1553 completed
# 310 out of 1553 completed
# 326 out of 1553 completed
# 341 out of 1553 completed
# 357 out of 1553 completed
# 372 out of 1553 completed
# 388 out of 1553 completed
# 403 out of 1553 completed
# 419 out of 1553 completed
# 434 out of 1553 completed
# 450 out of 1553 completed
# 465 out of 1553 completed
# 481 out of 1553 completed
# 496 out of 1553 completed
# 512 out of 1553 completed
# 528 out of 1553 completed
# 543 out of 1553 completed
# 559 out of 1553 completed
# 574 out of 1553 completed
# 590 out of 1553 completed
# 605 out of 1553 completed
# 621 out of 1553 completed
# 636 out of 1553 completed
# 652 out of 1553 completed
# 667 out of 1553 completed
# 683 out of 1553 completed
# 698 out of 1553 completed
# 714 out of 1553 completed
# 729 out of 1553 completed
# 745 out of 1553 completed
# 760 out of 1553 completed
# 776 out of 1553 completed
# 792 out of 1553 completed
# 807 out of 1553 completed
# 823 out of 1553 completed
# 838 out of 1553 completed
# 854 out of 1553 completed
# 869 out of 1553 completed
# 885 out of 1553 completed
# 900 out of 1553 completed
# 916 out of 1553 completed
# 931 out of 1553 completed
# 947 out of 1553 completed
# 962 out of 1553 completed
# 978 out of 1553 completed
# 993 out of 1553 completed
# 1009 out of 1553 completed
# 1024 out of 1553 completed
# 1040 out of 1553 completed
# 1056 out of 1553 completed
# 1071 out of 1553 completed
# 1087 out of 1553 completed
# 1102 out of 1553 completed
# 1118 out of 1553 completed
# 1133 out of 1553 completed
# 1149 out of 1553 completed
# 1164 out of 1553 completed
# 1180 out of 1553 completed
# 1195 out of 1553 completed
# 1211 out of 1553 completed
# 1226 out of 1553 completed
# 1242 out of 1553 completed
# 1257 out of 1553 completed
# 1273 out of 1553 completed
# 1288 out of 1553 completed
# 1304 out of 1553 completed
# 1320 out of 1553 completed
# 1335 out of 1553 completed
# 1351 out of 1553 completed
# 1366 out of 1553 completed
# 1382 out of 1553 completed
# 1397 out of 1553 completed
# 1413 out of 1553 completed
# 1428 out of 1553 completed
# 1444 out of 1553 completed
# 1459 out of 1553 completed
# 1475 out of 1553 completed
# 1490 out of 1553 completed
# 1506 out of 1553 completed
# 1521 out of 1553 completed
# 1537 out of 1553 completed
# All Wjets events have been created

# %%
print(len(listdir('CreatedImages/DYjets Images')),
len(listdir('CreatedImages/Wjets Images')),
len(listdir('CreatedImages/TTjets Images')))
# Out:
# 1370 1553 1239
