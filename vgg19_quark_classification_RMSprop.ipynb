# %% [markdown]
# #notebook setup

# %%
# !pip install google-auth --upgrade
# !pip install grpcio --upgrade
# Out:
# Requirement already up-to-date: google-auth in /usr/local/lib/python3.6/dist-packages (1.10.0)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (42.0.2)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (1.12.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth) (0.2.7)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (4.0.0)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth) (4.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already up-to-date: grpcio in /usr/local/lib/python3.6/dist-packages (1.26.0)
# Requirement already satisfied, skipping upgrade: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio) (1.12.0)

# %%
# !pip install -qq tf-nightly-gpu-2.0-preview
# Out:
#      |████████████████████████████████| 395.5MB 40kB/s
#      |████████████████████████████████| 3.8MB 31.1MB/s
#      |████████████████████████████████| 450kB 34.6MB/s

# %%
import tensorflow as tf
print(tf.__version__)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# 2.0.0-dev20191002
# Found GPU at: /device:GPU:0

# %%
import sys
try:
    import ujson as json
except ImportError:
    try:
        import simplejson as json
    except ImportError:
        import json

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.preprocessing import MinMaxScaler
import pywt
import os
from PIL import Image
# import tensorflow as tf
from glob import glob

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import Model,load_model,Sequential

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout,Flatten, Input
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
def plot_hist(input_history, filename):
  import os

  folder = ['acc', 'loss']

  directory = cwd + '/model_performance/'

  for f in folder:
    if not os.path.exists(directory + f):
      os.makedirs(directory + f)

  # summarize history for accuracy
  # fig, ax = plt.subplots(1,2)
  # plt.subplots_adjust(right=2)

  plt.plot(input_history.history['accuracy'])
  plt.plot(input_history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')

  plt.savefig(cwd+'/model_performance/acc/' + filename + '.jpg')
  plt.show()
  
  # summarize history for loss
  plt.plot(input_history.history['loss'])
  plt.plot(input_history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')

  
  plt.savefig(cwd+'/model_performance/loss/' + filename + '.jpg')

# %% [markdown]
# # Data prep

# %%
# %cd drive/'My Drive/CMS'
# !pwd
# Out:
# /content/drive/My Drive/CMS
# /content/drive/My Drive/CMS

# %%
img_folder = '/filtered_images'
# !ls 'filtered_images'
# Out:
# 0  1  2

# %% [markdown]
# class 0 : DYjets
# class 1 : TTjets
# class 2 : Wjets

# %% [markdown]
# ## Train val size setting

# %%
cwd = os.getcwd()
img_path = cwd + img_folder

train_val_size = 1200

df = {}
data = []
for idx, x in enumerate(os.listdir(img_path)):
  if x.isdigit() and idx < 3:
    for idx2, pic in enumerate(os.listdir(img_path+'/'+str(x))):
      if idx2 < train_val_size:
        data.append((img_path+ '/' + x + '/' + pic , x))

df = pd.DataFrame(data, columns=['filename', 'class'])
df['class'] = df['class'].astype(int)
#shuffle
df = df.sample(frac=1).reset_index(drop=True)

print(df.head())
print(len(df))
df.dtypes
# Out:
#                                             filename  class
# 0  /content/drive/My Drive/CMS/filtered_images/0/...      0
# 1  /content/drive/My Drive/CMS/filtered_images/2/...      2
# 2  /content/drive/My Drive/CMS/filtered_images/2/...      2
# 3  /content/drive/My Drive/CMS/filtered_images/0/...      0
# 4  /content/drive/My Drive/CMS/filtered_images/0/...      0
# 3600
# filename    object
# class        int64
# dtype: object

# %%
from collections import Counter
cnt = Counter(df['class'])
cnt
# Out:
# Counter({0: 1200, 1: 1200, 2: 1200})

# %%
# Split into train and validation sets
train_percentage = .8
val_percentage = 0.1
test_percentage = 0.1

train_length = int(len(df) * train_percentage)
df_train = df[:train_length]

val_length = int(len(df) * val_percentage)
df_val = df[train_length : train_length+val_length]

test_length = int(len(df) * test_percentage)
df_test = df[ train_length + val_length : ]

# shuffle 
df_train = df_train.sample(frac=1).reset_index(drop=True)
df_val = df_val.sample(frac=1).reset_index(drop=True)
df_test = df_test.sample(frac=1).reset_index(drop=True)

df_list = [df_train, df_val, df_test]
for df_part in df_list:
  print(len(df_part))
# Out:
# 2880
# 360
# 360

# %% [markdown]
# #### image parsing

# %%
# Reads an image from a file, decodes it into a tensor, and resizes it
# to a fixed shape.
img_rows, img_cols = 200,200
num_classes = len(set(df['class']))
batch_size = 120

def _parse_function(filename, label):
  image_string = tf.io.read_file(filename)
  image_decoded = tf.image.decode_jpeg(image_string)
  image_resized = tf.image.resize(image_decoded, [img_rows, img_cols])
  image_resized = tf.ensure_shape(image_resized ,shape=(img_rows, img_cols,3))
  label = tf.one_hot(label, num_classes)
  return image_resized, label

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((tf.cast(df_train['filename'].values, tf.string),
                                                    tf.cast(df_train['class'].values, tf.int32) ))
train_dataset = train_dataset.map(_parse_function)
train_dataset = train_dataset.shuffle(5000)
train_dataset = train_dataset.repeat()
train_dataset = train_dataset.batch(batch_size, drop_remainder=True)

# %%
valid_dataset = tf.data.Dataset.from_tensor_slices((tf.cast(df_val['filename'].values, tf.string),
                                                    tf.cast(df_val['class'].values, tf.int32) ))
valid_dataset = valid_dataset.map(_parse_function)
valid_dataset = valid_dataset.shuffle(5000)
valid_dataset = valid_dataset.repeat()
valid_dataset = valid_dataset.batch(batch_size, drop_remainder=True)

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((tf.cast(df_test['filename'].values, tf.string),
                                                    tf.cast(df_test['class'].values, tf.int32) ))
test_dataset = test_dataset.map(_parse_function)
test_dataset = test_dataset.shuffle(5000)
test_dataset = test_dataset.repeat()
test_dataset = test_dataset.batch(batch_size, drop_remainder=True)

# %%
train_dataset
# Out:
# <BatchDataset shapes: ((120, 200, 200, 3), (120, 3)), types: (tf.float32, tf.float32)>

# %% [markdown]
# # VGG19

# %% [markdown]
# ## Entirely frozen

# %%
base_vgg19_0 = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(200, 200, 3),pooling=None)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 3s 0us/step

# %%
# add a global spatial average pooling layer
x = base_vgg19_0.output

x = GlobalAveragePooling2D()(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# and a logits layer -- let's say we have 3 classes
predictions = Dense(3, activation='softmax')(x)

# %%
# this is the model we will train
base_vgg19_model = Model(inputs=base_vgg19_0.input, outputs=predictions)

# %%
for layer in base_vgg19_0.layers:
    print(layer.name)
    layer.trainable = False
# Out:
# input_1
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_conv4
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_conv4
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_conv4
# block5_pool

# %%
for layer in base_vgg19_model.layers:
    print(layer.name,' Trainable =',layer.trainable)
# Out:
# input_1  Trainable = False
# block1_conv1  Trainable = False
# block1_conv2  Trainable = False
# block1_pool  Trainable = False
# block2_conv1  Trainable = False
# block2_conv2  Trainable = False
# block2_pool  Trainable = False
# block3_conv1  Trainable = False
# block3_conv2  Trainable = False
# block3_conv3  Trainable = False
# block3_conv4  Trainable = False
# block3_pool  Trainable = False
# block4_conv1  Trainable = False
# block4_conv2  Trainable = False
# block4_conv3  Trainable = False
# block4_conv4  Trainable = False
# block4_pool  Trainable = False
# block5_conv1  Trainable = False
# block5_conv2  Trainable = False
# block5_conv3  Trainable = False
# block5_conv4  Trainable = False
# block5_pool  Trainable = False
# global_average_pooling2d  Trainable = True
# dense  Trainable = True
# dropout  Trainable = True
# dense_1  Trainable = True
# dropout_1  Trainable = True
# dense_2  Trainable = True
# dropout_2  Trainable = True
# dense_3  Trainable = True

# %%
opt = tf.keras.optimizers.Adam(lr=0.001)
opt1 = tf.keras.optimizers.RMSprop(lr=1e-4)
# compile the model (should be done *after* setting layers to non-trainable)
base_vgg19_model.compile(optimizer=opt1, loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #### fitting the model

# %%
train_steps = int(len(df_train)/batch_size) #total trains set / batch_size
val_steps = int(len(df_val)/batch_size)

print('train steps:',train_steps)
print('val steps:',val_steps)
epochs = 50

#es = EarlyStopping(monitor='accuracy', mode='max', verbose=1, patience=15)

base_vgg19_model_filepath = 'entirely_frozen_vgg19_rmsprop.h5'
mcp = ModelCheckpoint(base_vgg19_model_filepath, monitor='accuracy', save_best_only=True, mode='max')

### Train the model with validation 
entirely_frozen_vgg19_history = base_vgg19_model.fit( train_dataset, steps_per_epoch = train_steps,
                   epochs = epochs,
                   validation_data = valid_dataset,
                   validation_steps = val_steps,
                   callbacks= [#es, 
                               mcp])
# Out:
# train steps: 24
# val steps: 3
# Train for 24 steps, validate for 3 steps
# Epoch 1/50
# 24/24 [==============================] - 930s 39s/step - loss: 1.2282 - accuracy: 0.5031 - val_loss: 0.5632 - val_accuracy: 0.7333
# Epoch 2/50
# 24/24 [==============================] - 17s 717ms/step - loss: 0.8663 - accuracy: 0.6330 - val_loss: 0.5642 - val_accuracy: 0.7167
# Epoch 3/50
# 24/24 [==============================] - 17s 714ms/step - loss: 0.7530 - accuracy: 0.6649 - val_loss: 0.5389 - val_accuracy: 0.7333
# Epoch 4/50
# 24/24 [==============================] - 17s 705ms/step - loss: 0.6983 - accuracy: 0.6851 - val_loss: 0.5460 - val_accuracy: 0.7361
# Epoch 5/50
# 24/24 [==============================] - 17s 714ms/step - loss: 0.6657 - accuracy: 0.6951 - val_loss: 0.5132 - val_accuracy: 0.7556
# Epoch 6/50
# 24/24 [==============================] - 17s 707ms/step - loss: 0.6603 - accuracy: 0.7125 - val_loss: 0.4973 - val_accuracy: 0.7750
# Epoch 7/50
# 24/24 [==============================] - 17s 717ms/step - loss: 0.6198 - accuracy: 0.7149 - val_loss: 0.4930 - val_accuracy: 0.7750
# Epoch 8/50
# 24/24 [==============================] - 17s 715ms/step - loss: 0.6210 - accuracy: 0.7250 - val_loss: 0.4925 - val_accuracy: 0.7722
# Epoch 9/50
# 24/24 [==============================] - 17s 722ms/step - loss: 0.5867 - accuracy: 0.7292 - val_loss: 0.4901 - val_accuracy: 0.7833
# Epoch 10/50
# 24/24 [==============================] - 16s 664ms/step - loss: 0.5947 - accuracy: 0.7292 - val_loss: 0.4876 - val_accuracy: 0.7750
# Epoch 11/50
# 24/24 [==============================] - 17s 711ms/step - loss: 0.5789 - accuracy: 0.7406 - val_loss: 0.4875 - val_accuracy: 0.7778
# Epoch 12/50
# 24/24 [==============================] - 17s 711ms/step - loss: 0.5687 - accuracy: 0.7510 - val_loss: 0.4867 - val_accuracy: 0.7861
# Epoch 13/50
# 24/24 [==============================] - 17s 700ms/step - loss: 0.5665 - accuracy: 0.7451 - val_loss: 0.4869 - val_accuracy: 0.7750
# Epoch 14/50
# 24/24 [==============================] - 17s 704ms/step - loss: 0.5534 - accuracy: 0.7549 - val_loss: 0.4915 - val_accuracy: 0.7778
# Epoch 15/50
# 24/24 [==============================] - 16s 668ms/step - loss: 0.5532 - accuracy: 0.7549 - val_loss: 0.4841 - val_accuracy: 0.7806
# Epoch 16/50
# 24/24 [==============================] - 16s 663ms/step - loss: 0.5528 - accuracy: 0.7510 - val_loss: 0.4822 - val_accuracy: 0.7778
# Epoch 17/50
# 24/24 [==============================] - 17s 714ms/step - loss: 0.5521 - accuracy: 0.7556 - val_loss: 0.4781 - val_accuracy: 0.7861
# Epoch 18/50
# 24/24 [==============================] - 17s 714ms/step - loss: 0.5310 - accuracy: 0.7635 - val_loss: 0.4764 - val_accuracy: 0.7889
# Epoch 19/50
# 24/24 [==============================] - 18s 738ms/step - loss: 0.5281 - accuracy: 0.7698 - val_loss: 0.4762 - val_accuracy: 0.7833
# Epoch 20/50
# 24/24 [==============================] - 17s 711ms/step - loss: 0.5247 - accuracy: 0.7736 - val_loss: 0.4730 - val_accuracy: 0.7833
# Epoch 21/50
# 24/24 [==============================] - 17s 711ms/step - loss: 0.5192 - accuracy: 0.7753 - val_loss: 0.4701 - val_accuracy: 0.7833
# Epoch 22/50
# 24/24 [==============================] - 16s 663ms/step - loss: 0.5235 - accuracy: 0.7691 - val_loss: 0.4740 - val_accuracy: 0.7889
# Epoch 23/50
# 24/24 [==============================] - 17s 728ms/step - loss: 0.5277 - accuracy: 0.7795 - val_loss: 0.4675 - val_accuracy: 0.7917
# Epoch 24/50
# 24/24 [==============================] - 16s 669ms/step - loss: 0.5181 - accuracy: 0.7757 - val_loss: 0.4750 - val_accuracy: 0.7833
# Epoch 25/50
# 24/24 [==============================] - 17s 711ms/step - loss: 0.5082 - accuracy: 0.7802 - val_loss: 0.4725 - val_accuracy: 0.7861
# Epoch 26/50
# 24/24 [==============================] - 16s 671ms/step - loss: 0.5018 - accuracy: 0.7799 - val_loss: 0.4635 - val_accuracy: 0.7972
# Epoch 27/50
# 24/24 [==============================] - 16s 663ms/step - loss: 0.5037 - accuracy: 0.7733 - val_loss: 0.4634 - val_accuracy: 0.7917
# Epoch 28/50
# 24/24 [==============================] - 17s 709ms/step - loss: 0.5013 - accuracy: 0.7816 - val_loss: 0.4605 - val_accuracy: 0.7861
# Epoch 29/50
# 24/24 [==============================] - 18s 735ms/step - loss: 0.4889 - accuracy: 0.7851 - val_loss: 0.4623 - val_accuracy: 0.7889
# Epoch 30/50
# 24/24 [==============================] - 17s 707ms/step - loss: 0.4883 - accuracy: 0.7972 - val_loss: 0.4608 - val_accuracy: 0.7833
# Epoch 31/50
# 24/24 [==============================] - 16s 669ms/step - loss: 0.4833 - accuracy: 0.7802 - val_loss: 0.4591 - val_accuracy: 0.7944
# Epoch 32/50
# 24/24 [==============================] - 17s 690ms/step - loss: 0.4872 - accuracy: 0.7882 - val_loss: 0.4555 - val_accuracy: 0.7972
# Epoch 33/50
# 24/24 [==============================] - 16s 660ms/step - loss: 0.4807 - accuracy: 0.7913 - val_loss: 0.4549 - val_accuracy: 0.7944
# Epoch 34/50
# 24/24 [==============================] - 16s 659ms/step - loss: 0.4784 - accuracy: 0.7913 - val_loss: 0.4589 - val_accuracy: 0.7889
# Epoch 35/50
# 24/24 [==============================] - 16s 660ms/step - loss: 0.4730 - accuracy: 0.7872 - val_loss: 0.4510 - val_accuracy: 0.8000
# Epoch 36/50
# 24/24 [==============================] - 16s 664ms/step - loss: 0.4748 - accuracy: 0.7924 - val_loss: 0.4512 - val_accuracy: 0.7972
# Epoch 37/50
# 24/24 [==============================] - 16s 662ms/step - loss: 0.4678 - accuracy: 0.7875 - val_loss: 0.4503 - val_accuracy: 0.8000
# Epoch 38/50
# 24/24 [==============================] - 17s 714ms/step - loss: 0.4629 - accuracy: 0.7986 - val_loss: 0.4497 - val_accuracy: 0.8056
# Epoch 39/50
# 24/24 [==============================] - 16s 677ms/step - loss: 0.4572 - accuracy: 0.7983 - val_loss: 0.4477 - val_accuracy: 0.8111
# Epoch 40/50
# 24/24 [==============================] - 17s 713ms/step - loss: 0.4535 - accuracy: 0.8010 - val_loss: 0.4475 - val_accuracy: 0.7972
# Epoch 41/50
# 24/24 [==============================] - 16s 669ms/step - loss: 0.4595 - accuracy: 0.7941 - val_loss: 0.4453 - val_accuracy: 0.8056
# Epoch 42/50
# 24/24 [==============================] - 16s 665ms/step - loss: 0.4546 - accuracy: 0.7993 - val_loss: 0.4463 - val_accuracy: 0.8056
# Epoch 43/50
# 24/24 [==============================] - 17s 710ms/step - loss: 0.4440 - accuracy: 0.8076 - val_loss: 0.4426 - val_accuracy: 0.8000
# Epoch 44/50
# 24/24 [==============================] - 16s 671ms/step - loss: 0.4458 - accuracy: 0.8021 - val_loss: 0.4416 - val_accuracy: 0.8056
# Epoch 45/50
# 24/24 [==============================] - 16s 671ms/step - loss: 0.4474 - accuracy: 0.8056 - val_loss: 0.4472 - val_accuracy: 0.7917
# Epoch 46/50
# 24/24 [==============================] - 16s 663ms/step - loss: 0.4488 - accuracy: 0.7972 - val_loss: 0.4445 - val_accuracy: 0.8028
# Epoch 47/50
# 24/24 [==============================] - 17s 708ms/step - loss: 0.4359 - accuracy: 0.8087 - val_loss: 0.4410 - val_accuracy: 0.8083
# Epoch 48/50
# 24/24 [==============================] - 17s 716ms/step - loss: 0.4307 - accuracy: 0.8111 - val_loss: 0.4488 - val_accuracy: 0.8083
# Epoch 49/50
# 24/24 [==============================] - 16s 668ms/step - loss: 0.4351 - accuracy: 0.8000 - val_loss: 0.4437 - val_accuracy: 0.8083
# Epoch 50/50
# 24/24 [==============================] - 16s 664ms/step - loss: 0.4294 - accuracy: 0.8101 - val_loss: 0.4413 - val_accuracy: 0.8056

# %% [markdown]
# #### testing the model

# %%
test_steps = int(len(df_test)/batch_size)

metrics = base_vgg19_model.evaluate(test_dataset,
                   steps = test_steps)
print("model accuracy:",metrics[1])
# Out:
# 3/3 [==============================] - 101s 34s/step - loss: 0.5608 - accuracy: 0.7694
# model accuracy: 0.76944447

# %% [markdown]
# #### plotting training

# %%
plot_hist(entirely_frozen_vgg19_history, 'entirely_frozen_vgg19_rmsprop')

# %% [markdown]
# #### saving the history of the fitting

# %%
with open(cwd + '/trainHistoryDict/entirely_frozen_vgg19_rmsprop_history.p', 'wb') as file_pi:
        pickle.dump(entirely_frozen_vgg19_history.history, file_pi)
print('history saved')
# Out:
# history saved

# %% [markdown]
# ## Few layers unfrozen

# %% [markdown]
# #### loading model

# %%
base_vgg19_1 = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(200, 200, 3),pooling=None)

# %% [markdown]
# #### modifying slightly

# %%
# add a global spatial average pooling layer
x = base_vgg19_1.output

x = GlobalAveragePooling2D()(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# and a logits layer -- let's say we have 3 classes
predictions = Dense(3, activation='softmax')(x)

# %% [markdown]
# #### creating model object

# %%
# this is the model we will train
few_unfrozen_vgg19_model = Model(inputs=base_vgg19_1.input, outputs=predictions)

# %%
for layer in base_vgg19_1.layers:
    print(layer.name)
    layer.trainable = False
# Out:
# input_2
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_conv4
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_conv4
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_conv4
# block5_pool

# %%
trainable_count = 0
per_layers = 0.2
num_model_layers = len(base_vgg19_1.layers)
starting_layer = int( num_model_layers * (1 - per_layers))
true_per_trained = (num_model_layers - starting_layer) / num_model_layers


print('true percentage of model trainable:', true_per_trained)
# Out:
# true percentage of model trainable: 0.22727272727272727

# %%
set_trainable = False
for idx, layer in enumerate(base_vgg19_1.layers):
    if idx == starting_layer:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
        trainable_count += 1
    else:
        layer.trainable = False

# %%
for layer in few_unfrozen_vgg19_model.layers:
    print(layer.name,layer.trainable)
# Out:
# input_2 False
# block1_conv1 False
# block1_conv2 False
# block1_pool False
# block2_conv1 False
# block2_conv2 False
# block2_pool False
# block3_conv1 False
# block3_conv2 False
# block3_conv3 False
# block3_conv4 False
# block3_pool False
# block4_conv1 False
# block4_conv2 False
# block4_conv3 False
# block4_conv4 False
# block4_pool False
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_conv4 True
# block5_pool True
# global_average_pooling2d_1 True
# dense_4 True
# dropout_3 True
# dense_5 True
# dropout_4 True
# dense_6 True
# dropout_5 True
# dense_7 True

# %%
opt = tf.keras.optimizers.Adam(lr=0.001)
# compile the model (should be done *after* setting layers to non-trainable)
few_unfrozen_vgg19_model.compile(optimizer=opt1, loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #### fitting the model

# %%
train_steps = int(len(df_train)/batch_size) #total trains set / batch_size
val_steps = int(len(df_val)/batch_size)

print('train steps:',train_steps)
print('val steps:',val_steps)

epochs = 50


model_filepath = 'few_unfrozen_vgg19_rmsprop.h5'
mcp = ModelCheckpoint(model_filepath, monitor='accuracy', save_best_only=True, mode='max')

# Train the model with validation 
few_unfrozen_vgg19_history = few_unfrozen_vgg19_model.fit( train_dataset, steps_per_epoch = train_steps,
                   epochs = epochs,
                   validation_data = valid_dataset,
                   validation_steps = val_steps,
                   callbacks=[mcp])
# Out:
# train steps: 24
# val steps: 3
# Train for 24 steps, validate for 3 steps
# Epoch 1/50
# 24/24 [==============================] - 18s 770ms/step - loss: 0.9621 - accuracy: 0.5323 - val_loss: 0.5483 - val_accuracy: 0.7306
# Epoch 2/50
# 24/24 [==============================] - 18s 757ms/step - loss: 0.7257 - accuracy: 0.6736 - val_loss: 0.5759 - val_accuracy: 0.7500
# Epoch 3/50
# 24/24 [==============================] - 19s 781ms/step - loss: 0.6299 - accuracy: 0.7135 - val_loss: 0.5996 - val_accuracy: 0.7722
# Epoch 4/50
# 24/24 [==============================] - 18s 750ms/step - loss: 0.5932 - accuracy: 0.7420 - val_loss: 0.6125 - val_accuracy: 0.7361
# Epoch 5/50
# 24/24 [==============================] - 18s 748ms/step - loss: 0.5715 - accuracy: 0.7531 - val_loss: 0.6449 - val_accuracy: 0.7500
# Epoch 6/50
# 24/24 [==============================] - 18s 759ms/step - loss: 0.5328 - accuracy: 0.7740 - val_loss: 0.6587 - val_accuracy: 0.7361
# Epoch 7/50
# 24/24 [==============================] - 18s 748ms/step - loss: 0.5227 - accuracy: 0.7826 - val_loss: 0.4983 - val_accuracy: 0.7833
# Epoch 8/50
# 24/24 [==============================] - 18s 758ms/step - loss: 0.4811 - accuracy: 0.7924 - val_loss: 0.5188 - val_accuracy: 0.7917
# Epoch 9/50
# 24/24 [==============================] - 19s 794ms/step - loss: 0.4773 - accuracy: 0.7937 - val_loss: 0.5191 - val_accuracy: 0.7944
# Epoch 10/50
# 24/24 [==============================] - 18s 747ms/step - loss: 0.4431 - accuracy: 0.8042 - val_loss: 0.5281 - val_accuracy: 0.8000
# Epoch 11/50
# 24/24 [==============================] - 19s 771ms/step - loss: 0.4340 - accuracy: 0.8073 - val_loss: 0.4933 - val_accuracy: 0.7889
# Epoch 12/50
# 24/24 [==============================] - 18s 759ms/step - loss: 0.4148 - accuracy: 0.8191 - val_loss: 0.6317 - val_accuracy: 0.7278
# Epoch 13/50
# 24/24 [==============================] - 17s 690ms/step - loss: 0.4118 - accuracy: 0.8188 - val_loss: 0.5098 - val_accuracy: 0.8000
# Epoch 14/50
# 24/24 [==============================] - 18s 759ms/step - loss: 0.3888 - accuracy: 0.8208 - val_loss: 0.5508 - val_accuracy: 0.7889
# Epoch 15/50
# 24/24 [==============================] - 18s 755ms/step - loss: 0.3811 - accuracy: 0.8233 - val_loss: 0.5111 - val_accuracy: 0.7889
# Epoch 16/50
# 24/24 [==============================] - 19s 775ms/step - loss: 0.3401 - accuracy: 0.8368 - val_loss: 0.7520 - val_accuracy: 0.7833
# Epoch 17/50
# 24/24 [==============================] - 17s 688ms/step - loss: 0.3431 - accuracy: 0.8368 - val_loss: 0.5935 - val_accuracy: 0.7889
# Epoch 18/50
# 24/24 [==============================] - 17s 688ms/step - loss: 0.3346 - accuracy: 0.8337 - val_loss: 0.5875 - val_accuracy: 0.7972
# Epoch 19/50
# 24/24 [==============================] - 18s 748ms/step - loss: 0.3154 - accuracy: 0.8535 - val_loss: 0.8235 - val_accuracy: 0.7444
# Epoch 20/50
# 24/24 [==============================] - 18s 753ms/step - loss: 0.3088 - accuracy: 0.8538 - val_loss: 0.6317 - val_accuracy: 0.7333
# Epoch 21/50
# 24/24 [==============================] - 18s 755ms/step - loss: 0.2962 - accuracy: 0.8625 - val_loss: 0.8810 - val_accuracy: 0.7194
# Epoch 22/50
# 24/24 [==============================] - 17s 694ms/step - loss: 0.3010 - accuracy: 0.8573 - val_loss: 0.6003 - val_accuracy: 0.7806
# Epoch 23/50
# 24/24 [==============================] - 17s 688ms/step - loss: 0.3434 - accuracy: 0.8490 - val_loss: 0.6237 - val_accuracy: 0.7333
# Epoch 24/50
# 24/24 [==============================] - 18s 761ms/step - loss: 0.2758 - accuracy: 0.8656 - val_loss: 0.6281 - val_accuracy: 0.7833
# Epoch 25/50
# 24/24 [==============================] - 18s 753ms/step - loss: 0.2544 - accuracy: 0.8698 - val_loss: 0.7698 - val_accuracy: 0.7861
# Epoch 26/50
# 24/24 [==============================] - 18s 757ms/step - loss: 0.2627 - accuracy: 0.8809 - val_loss: 0.6413 - val_accuracy: 0.7750
# Epoch 27/50
# 24/24 [==============================] - 18s 754ms/step - loss: 0.2529 - accuracy: 0.8878 - val_loss: 0.6851 - val_accuracy: 0.7417
# Epoch 28/50
# 24/24 [==============================] - 17s 690ms/step - loss: 0.2411 - accuracy: 0.8833 - val_loss: 0.5999 - val_accuracy: 0.7472
# Epoch 29/50
# 24/24 [==============================] - 17s 689ms/step - loss: 0.2614 - accuracy: 0.8840 - val_loss: 0.7048 - val_accuracy: 0.7667
# Epoch 30/50
# 24/24 [==============================] - 18s 752ms/step - loss: 0.1938 - accuracy: 0.9042 - val_loss: 1.0625 - val_accuracy: 0.7806
# Epoch 31/50
# 24/24 [==============================] - 17s 711ms/step - loss: 0.2183 - accuracy: 0.9038 - val_loss: 1.0250 - val_accuracy: 0.6972
# Epoch 32/50
# 24/24 [==============================] - 17s 692ms/step - loss: 0.2126 - accuracy: 0.9031 - val_loss: 0.7878 - val_accuracy: 0.7417
# Epoch 33/50
# 24/24 [==============================] - 16s 684ms/step - loss: 0.2560 - accuracy: 0.8962 - val_loss: 0.9224 - val_accuracy: 0.7861
# Epoch 34/50
# 24/24 [==============================] - 18s 757ms/step - loss: 0.1845 - accuracy: 0.9135 - val_loss: 0.9138 - val_accuracy: 0.7944
# Epoch 35/50
# 24/24 [==============================] - 16s 683ms/step - loss: 0.2278 - accuracy: 0.9049 - val_loss: 0.9863 - val_accuracy: 0.7583
# Epoch 36/50
# 24/24 [==============================] - 18s 754ms/step - loss: 0.1851 - accuracy: 0.9194 - val_loss: 1.1189 - val_accuracy: 0.7250
# Epoch 37/50
# 24/24 [==============================] - 17s 689ms/step - loss: 0.1918 - accuracy: 0.9153 - val_loss: 0.8297 - val_accuracy: 0.7167
# Epoch 38/50
# 24/24 [==============================] - 17s 691ms/step - loss: 0.1790 - accuracy: 0.9194 - val_loss: 1.0248 - val_accuracy: 0.7333
# Epoch 39/50
# 24/24 [==============================] - 18s 757ms/step - loss: 0.1632 - accuracy: 0.9281 - val_loss: 1.0666 - val_accuracy: 0.7667
# Epoch 40/50
# 24/24 [==============================] - 18s 760ms/step - loss: 0.1465 - accuracy: 0.9323 - val_loss: 1.0508 - val_accuracy: 0.7306
# Epoch 41/50
# 24/24 [==============================] - 18s 748ms/step - loss: 0.1567 - accuracy: 0.9337 - val_loss: 1.6264 - val_accuracy: 0.7694
# Epoch 42/50
# 24/24 [==============================] - 17s 694ms/step - loss: 0.2031 - accuracy: 0.9267 - val_loss: 1.3803 - val_accuracy: 0.7667
# Epoch 43/50
# 24/24 [==============================] - 17s 689ms/step - loss: 0.2692 - accuracy: 0.9128 - val_loss: 1.2788 - val_accuracy: 0.7500
# Epoch 44/50
# 24/24 [==============================] - 18s 764ms/step - loss: 0.1172 - accuracy: 0.9472 - val_loss: 1.3060 - val_accuracy: 0.7694
# Epoch 45/50
# 24/24 [==============================] - 17s 689ms/step - loss: 0.1427 - accuracy: 0.9385 - val_loss: 1.3993 - val_accuracy: 0.7361
# Epoch 46/50
# 24/24 [==============================] - 18s 758ms/step - loss: 0.1307 - accuracy: 0.9479 - val_loss: 1.3602 - val_accuracy: 0.7694
# Epoch 47/50
# 24/24 [==============================] - 17s 700ms/step - loss: 0.1881 - accuracy: 0.9233 - val_loss: 0.9698 - val_accuracy: 0.7667
# Epoch 48/50
# 24/24 [==============================] - 17s 691ms/step - loss: 0.1302 - accuracy: 0.9462 - val_loss: 0.9894 - val_accuracy: 0.7056
# Epoch 49/50
# 24/24 [==============================] - 18s 759ms/step - loss: 0.1269 - accuracy: 0.9552 - val_loss: 1.3607 - val_accuracy: 0.7750
# Epoch 50/50
# 24/24 [==============================] - 17s 696ms/step - loss: 0.1351 - accuracy: 0.9406 - val_loss: 1.4468 - val_accuracy: 0.7528

# %% [markdown]
# #### testing the model

# %%
test_steps = int(len(df_test)/batch_size)

metrics = few_unfrozen_vgg19_model.evaluate(test_dataset,
                   steps = test_steps)
print("model accuracy:",metrics[1])
# Out:
# 3/3 [==============================] - 2s 580ms/step - loss: 3.2673 - accuracy: 0.7250
# model accuracy: 0.725

# %% [markdown]
# #### plotting training

# %%
plot_hist(few_unfrozen_vgg19_history, 'few_unfrozen_vgg19_rmsprop')

# %% [markdown]
# #### saving the history of the fitting

# %%
with open(cwd + '/trainHistoryDict/few_unfrozen_vgg19_rmsprop_history.p', 'wb') as file_pi:
        pickle.dump(few_unfrozen_vgg19_history.history, file_pi)
print('history saved')
# Out:
# history saved

# %% [markdown]
# ## Many layers unfrozen

# %% [markdown]
# #### loading model

# %%
base_vgg19_2 = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(200, 200, 3),pooling=None)

# %% [markdown]
# #### modifying slightly

# %%
# add a global spatial average pooling layer
x = base_vgg19_2.output

x = GlobalAveragePooling2D()(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# and a logits layer -- let's say we have 3 classes
predictions = Dense(3, activation='softmax')(x)

# %% [markdown]
# #### creating model object

# %%
# this is the model we will train
many_unfrozen_vgg19_model = Model(inputs=base_vgg19_2.input, outputs=predictions)

# %%
for layer in base_vgg19_2.layers:
    print(layer.name)
    layer.trainable = False
# Out:
# input_3
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_conv4
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_conv4
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_conv4
# block5_pool

# %%
trainable_count = 0
per_layers = 0.7
num_model_layers = len(base_vgg19_2.layers)
starting_layer = int( num_model_layers * (1 - per_layers))
true_per_trained = (num_model_layers - starting_layer) / num_model_layers


print('true percentage of model trainable:', true_per_trained)
# Out:
# true percentage of model trainable: 0.7272727272727273

# %%
set_trainable = False
for idx, layer in enumerate(base_vgg19_2.layers):
    if idx == starting_layer:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
        trainable_count += 1
    else:
        layer.trainable = False

# %%
for layer in many_unfrozen_vgg19_model.layers:
    print(layer.name,layer.trainable)
# Out:
# input_3 False
# block1_conv1 False
# block1_conv2 False
# block1_pool False
# block2_conv1 False
# block2_conv2 False
# block2_pool True
# block3_conv1 True
# block3_conv2 True
# block3_conv3 True
# block3_conv4 True
# block3_pool True
# block4_conv1 True
# block4_conv2 True
# block4_conv3 True
# block4_conv4 True
# block4_pool True
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_conv4 True
# block5_pool True
# global_average_pooling2d_2 True
# dense_8 True
# dropout_6 True
# dense_9 True
# dropout_7 True
# dense_10 True
# dropout_8 True
# dense_11 True

# %%
opt = tf.keras.optimizers.Adam(lr=0.001)
# compile the model (should be done *after* setting layers to non-trainable)
many_unfrozen_vgg19_model.compile(optimizer=opt1, loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #### fitting the model

# %%
train_steps = int(len(df_train)/batch_size) #total trains set / batch_size
val_steps = int(len(df_val)/batch_size)

print('train steps:',train_steps)
print('val steps:',val_steps)

epochs = 50


model_filepath = 'many_unfrozen_vgg19_rmsprop.h5'
mcp = ModelCheckpoint(model_filepath, monitor='accuracy', save_best_only=True, mode='max')

# Train the model with validation 
many_unfrozen_vgg19_history = many_unfrozen_vgg19_model.fit( train_dataset, steps_per_epoch = train_steps,
                   epochs = epochs,
                   validation_data = valid_dataset,
                   validation_steps = val_steps,
                   callbacks=[mcp])
# Out:
# train steps: 24
# val steps: 3
# Train for 24 steps, validate for 3 steps
# Epoch 1/50
# 24/24 [==============================] - 27s 1s/step - loss: 1.2417 - accuracy: 0.3396 - val_loss: 1.0883 - val_accuracy: 0.3389
# Epoch 2/50
# 24/24 [==============================] - 26s 1s/step - loss: 1.1491 - accuracy: 0.3434 - val_loss: 1.0975 - val_accuracy: 0.3389
# Epoch 3/50
# 24/24 [==============================] - 25s 1s/step - loss: 1.0992 - accuracy: 0.3580 - val_loss: 0.8757 - val_accuracy: 0.5889
# Epoch 4/50
# 24/24 [==============================] - 25s 1s/step - loss: 1.1336 - accuracy: 0.4056 - val_loss: 0.8788 - val_accuracy: 0.4778
# Epoch 5/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.8767 - accuracy: 0.5628 - val_loss: 0.6184 - val_accuracy: 0.6389
# Epoch 6/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.7442 - accuracy: 0.6299 - val_loss: 0.6830 - val_accuracy: 0.6667
# Epoch 7/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.7409 - accuracy: 0.6639 - val_loss: 0.5684 - val_accuracy: 0.7056
# Epoch 8/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.6396 - accuracy: 0.7156 - val_loss: 0.5948 - val_accuracy: 0.7444
# Epoch 9/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.6047 - accuracy: 0.7410 - val_loss: 0.5540 - val_accuracy: 0.7111
# Epoch 10/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.5874 - accuracy: 0.7556 - val_loss: 0.6145 - val_accuracy: 0.7194
# Epoch 11/50
# 24/24 [==============================] - 23s 950ms/step - loss: 0.5890 - accuracy: 0.7535 - val_loss: 0.5020 - val_accuracy: 0.7472
# Epoch 12/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.5388 - accuracy: 0.7795 - val_loss: 0.5270 - val_accuracy: 0.7556
# Epoch 13/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.5105 - accuracy: 0.7816 - val_loss: 0.5651 - val_accuracy: 0.7444
# Epoch 14/50
# 24/24 [==============================] - 23s 955ms/step - loss: 0.5155 - accuracy: 0.7812 - val_loss: 0.4763 - val_accuracy: 0.7528
# Epoch 15/50
# 24/24 [==============================] - 26s 1s/step - loss: 0.4973 - accuracy: 0.7878 - val_loss: 0.5094 - val_accuracy: 0.7972
# Epoch 16/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.4819 - accuracy: 0.7899 - val_loss: 0.4502 - val_accuracy: 0.7889
# Epoch 17/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.4783 - accuracy: 0.7944 - val_loss: 0.5439 - val_accuracy: 0.7611
# Epoch 18/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.4627 - accuracy: 0.7948 - val_loss: 0.4779 - val_accuracy: 0.7722
# Epoch 19/50
# 24/24 [==============================] - 26s 1s/step - loss: 0.4452 - accuracy: 0.8101 - val_loss: 0.5062 - val_accuracy: 0.7333
# Epoch 20/50
# 24/24 [==============================] - 23s 954ms/step - loss: 0.4233 - accuracy: 0.8101 - val_loss: 0.5019 - val_accuracy: 0.7833
# Epoch 21/50
# 24/24 [==============================] - 26s 1s/step - loss: 0.4034 - accuracy: 0.8115 - val_loss: 0.5273 - val_accuracy: 0.7583
# Epoch 22/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.4141 - accuracy: 0.8142 - val_loss: 0.5579 - val_accuracy: 0.7667
# Epoch 23/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.3973 - accuracy: 0.8194 - val_loss: 0.5511 - val_accuracy: 0.7361
# Epoch 24/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.3859 - accuracy: 0.8215 - val_loss: 0.5718 - val_accuracy: 0.7583
# Epoch 25/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.3696 - accuracy: 0.8281 - val_loss: 0.5741 - val_accuracy: 0.7833
# Epoch 26/50
# 24/24 [==============================] - 26s 1s/step - loss: 0.3630 - accuracy: 0.8396 - val_loss: 0.5775 - val_accuracy: 0.7528
# Epoch 27/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.3433 - accuracy: 0.8434 - val_loss: 0.7009 - val_accuracy: 0.7361
# Epoch 28/50
# 24/24 [==============================] - 23s 952ms/step - loss: 0.3466 - accuracy: 0.8375 - val_loss: 0.5494 - val_accuracy: 0.7528
# Epoch 29/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.3231 - accuracy: 0.8528 - val_loss: 0.6180 - val_accuracy: 0.7778
# Epoch 30/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.3178 - accuracy: 0.8552 - val_loss: 0.6289 - val_accuracy: 0.7472
# Epoch 31/50
# 24/24 [==============================] - 26s 1s/step - loss: 0.2806 - accuracy: 0.8722 - val_loss: 0.5735 - val_accuracy: 0.7722
# Epoch 32/50
# 24/24 [==============================] - 23s 948ms/step - loss: 0.2908 - accuracy: 0.8670 - val_loss: 0.7743 - val_accuracy: 0.7667
# Epoch 33/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.2905 - accuracy: 0.8774 - val_loss: 0.7554 - val_accuracy: 0.7389
# Epoch 34/50
# 24/24 [==============================] - 26s 1s/step - loss: 0.2635 - accuracy: 0.8788 - val_loss: 0.7813 - val_accuracy: 0.7861
# Epoch 35/50
# 24/24 [==============================] - 23s 951ms/step - loss: 0.2629 - accuracy: 0.8781 - val_loss: 0.7780 - val_accuracy: 0.7472
# Epoch 36/50
# 24/24 [==============================] - 23s 978ms/step - loss: 0.2684 - accuracy: 0.8771 - val_loss: 0.7036 - val_accuracy: 0.7861
# Epoch 37/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.2208 - accuracy: 0.8965 - val_loss: 0.8007 - val_accuracy: 0.7556
# Epoch 38/50
# 24/24 [==============================] - 23s 945ms/step - loss: 0.2592 - accuracy: 0.8858 - val_loss: 0.9079 - val_accuracy: 0.7583
# Epoch 39/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.2285 - accuracy: 0.8986 - val_loss: 0.7685 - val_accuracy: 0.7694
# Epoch 40/50
# 24/24 [==============================] - 23s 952ms/step - loss: 0.2222 - accuracy: 0.8917 - val_loss: 0.9217 - val_accuracy: 0.7472
# Epoch 41/50
# 24/24 [==============================] - 23s 944ms/step - loss: 0.2504 - accuracy: 0.8865 - val_loss: 0.9731 - val_accuracy: 0.7611
# Epoch 42/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.1731 - accuracy: 0.9191 - val_loss: 1.0129 - val_accuracy: 0.7389
# Epoch 43/50
# 24/24 [==============================] - 23s 953ms/step - loss: 0.3216 - accuracy: 0.8833 - val_loss: 0.7940 - val_accuracy: 0.7667
# Epoch 44/50
# 24/24 [==============================] - 23s 942ms/step - loss: 0.1833 - accuracy: 0.9167 - val_loss: 1.1323 - val_accuracy: 0.7306
# Epoch 45/50
# 24/24 [==============================] - 23s 946ms/step - loss: 0.1806 - accuracy: 0.9184 - val_loss: 1.1205 - val_accuracy: 0.7361
# Epoch 46/50
# 24/24 [==============================] - 23s 956ms/step - loss: 0.2576 - accuracy: 0.8993 - val_loss: 0.8325 - val_accuracy: 0.7722
# Epoch 47/50
# 24/24 [==============================] - 26s 1s/step - loss: 0.1778 - accuracy: 0.9306 - val_loss: 0.9188 - val_accuracy: 0.7667
# Epoch 48/50
# 24/24 [==============================] - 23s 965ms/step - loss: 0.2552 - accuracy: 0.9184 - val_loss: 1.0981 - val_accuracy: 0.7167
# Epoch 49/50
# 24/24 [==============================] - 26s 1s/step - loss: 0.1529 - accuracy: 0.9365 - val_loss: 0.9858 - val_accuracy: 0.7611
# Epoch 50/50
# 24/24 [==============================] - 23s 942ms/step - loss: 0.1885 - accuracy: 0.9253 - val_loss: 1.0960 - val_accuracy: 0.7722

# %% [markdown]
# #### testing the model

# %%
test_steps = int(len(df_test)/batch_size)

metrics = many_unfrozen_vgg19_model.evaluate(test_dataset,
                   steps = test_steps)
print("model accuracy:",metrics[1])
# Out:
# 3/3 [==============================] - 2s 564ms/step - loss: 1.7182 - accuracy: 0.7278
# model accuracy: 0.7277778

# %% [markdown]
# #### plotting training

# %%
plot_hist(many_unfrozen_vgg19_history, 'many_unfrozen_vgg19_rmsprop')

# %% [markdown]
# #### saving the history of the fitting

# %%
with open(cwd + '/trainHistoryDict/many_unfrozen_vgg19_rmsprop_history.p', 'wb') as file_pi:
        pickle.dump(many_unfrozen_vgg19_history.history, file_pi)
print('history saved')
# Out:
# history saved

# %% [markdown]
# ## entirely unfrozen

# %%
input_shapes = (200, 200, 3)
base_vgg19_3 = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=input_shapes,pooling=None)

# %% [markdown]
# #### modifying slightly

# %%
# add a global spatial average pooling layer
x = base_vgg19_3.output

x = GlobalAveragePooling2D()(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)

x = Dropout(0.3)(x)

# and a logits layer -- let's say we have 3 classes
predictions = Dense(3, activation='softmax')(x)

# %% [markdown]
# #### creating model object

# %%
# this is the model we will train
unfrozen_vgg19_model = Model(inputs=base_vgg19_3.input, outputs=predictions)

# %%
for layer in unfrozen_vgg19_model.layers:
    print(layer.name)
    layer.trainable = True
# Out:
# input_4
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_conv4
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_conv4
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_conv4
# block5_pool
# global_average_pooling2d_3
# dense_12
# dropout_9
# dense_13
# dropout_10
# dense_14
# dropout_11
# dense_15

# %%
for layer in unfrozen_vgg19_model.layers:
    print(layer.name,' Trainable =',layer.trainable)
# Out:
# input_4  Trainable = True
# block1_conv1  Trainable = True
# block1_conv2  Trainable = True
# block1_pool  Trainable = True
# block2_conv1  Trainable = True
# block2_conv2  Trainable = True
# block2_pool  Trainable = True
# block3_conv1  Trainable = True
# block3_conv2  Trainable = True
# block3_conv3  Trainable = True
# block3_conv4  Trainable = True
# block3_pool  Trainable = True
# block4_conv1  Trainable = True
# block4_conv2  Trainable = True
# block4_conv3  Trainable = True
# block4_conv4  Trainable = True
# block4_pool  Trainable = True
# block5_conv1  Trainable = True
# block5_conv2  Trainable = True
# block5_conv3  Trainable = True
# block5_conv4  Trainable = True
# block5_pool  Trainable = True
# global_average_pooling2d_3  Trainable = True
# dense_12  Trainable = True
# dropout_9  Trainable = True
# dense_13  Trainable = True
# dropout_10  Trainable = True
# dense_14  Trainable = True
# dropout_11  Trainable = True
# dense_15  Trainable = True

# %%
unfrozen_vgg19_model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 200, 200, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 200, 200, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 200, 200, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 100, 100, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 100, 100, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 100, 100, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 50, 50, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 50, 50, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 25, 25, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 25, 25, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 20,813,891
# Trainable params: 20,813,891
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### setting the optimizer

# %%
opt = tf.keras.optimizers.Adam(lr=0.001)
opt1 = tf.keras.optimizers.RMSprop(lr=1e-4)
# compile the model (should be done *after* setting layers to non-trainable)
unfrozen_vgg19_model.compile(optimizer=opt1, loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #### fitting the model

# %%
train_steps = int(len(df_train)/batch_size) #total trains set / batch_size
val_steps = int(len(df_val)/batch_size)

print('train steps:',train_steps)
print('val steps:',val_steps)

epochs = 50


model_filepath = 'unfrozen_vgg19_rmsprop.h5'
mcp = ModelCheckpoint(model_filepath, monitor='accuracy', save_best_only=True, mode='max')

# Train the model with validation 
unfrozen_vgg19_history = unfrozen_vgg19_model.fit( train_dataset, steps_per_epoch = train_steps,
                   epochs = epochs,
                   validation_data = valid_dataset,
                   validation_steps = val_steps,
                   callbacks=[mcp])
# Out:
# train steps: 24
# val steps: 3
# Train for 24 steps, validate for 3 steps
# Epoch 1/50
# 24/24 [==============================] - 33s 1s/step - loss: 1.2376 - accuracy: 0.3368 - val_loss: 1.0960 - val_accuracy: 0.3333
# Epoch 2/50
# 24/24 [==============================] - 30s 1s/step - loss: 1.1076 - accuracy: 0.3438 - val_loss: 1.0936 - val_accuracy: 0.3389
# Epoch 3/50
# 24/24 [==============================] - 31s 1s/step - loss: 1.0960 - accuracy: 0.3441 - val_loss: 1.0996 - val_accuracy: 0.3417
# Epoch 4/50
# 24/24 [==============================] - 31s 1s/step - loss: 1.0927 - accuracy: 0.3545 - val_loss: 1.0406 - val_accuracy: 0.3389
# Epoch 5/50
# 24/24 [==============================] - 31s 1s/step - loss: 1.0245 - accuracy: 0.4434 - val_loss: 2.9290 - val_accuracy: 0.3389
# Epoch 6/50
# 24/24 [==============================] - 31s 1s/step - loss: 1.0731 - accuracy: 0.4795 - val_loss: 0.8965 - val_accuracy: 0.5333
# Epoch 7/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.7828 - accuracy: 0.5872 - val_loss: 0.8125 - val_accuracy: 0.5944
# Epoch 8/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.7356 - accuracy: 0.6122 - val_loss: 0.6122 - val_accuracy: 0.6500
# Epoch 9/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.7064 - accuracy: 0.6590 - val_loss: 0.5802 - val_accuracy: 0.7444
# Epoch 10/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.6322 - accuracy: 0.7285 - val_loss: 0.6749 - val_accuracy: 0.7472
# Epoch 11/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.6191 - accuracy: 0.7469 - val_loss: 0.5297 - val_accuracy: 0.7750
# Epoch 12/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.5518 - accuracy: 0.7688 - val_loss: 0.5240 - val_accuracy: 0.7222
# Epoch 13/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.5490 - accuracy: 0.7740 - val_loss: 0.6035 - val_accuracy: 0.7278
# Epoch 14/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.5263 - accuracy: 0.7840 - val_loss: 0.4792 - val_accuracy: 0.7889
# Epoch 15/50
# 24/24 [==============================] - 28s 1s/step - loss: 0.5145 - accuracy: 0.7840 - val_loss: 0.5900 - val_accuracy: 0.7389
# Epoch 16/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.4878 - accuracy: 0.7983 - val_loss: 0.4962 - val_accuracy: 0.7972
# Epoch 17/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.5002 - accuracy: 0.7903 - val_loss: 0.5335 - val_accuracy: 0.7611
# Epoch 18/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.4833 - accuracy: 0.8038 - val_loss: 0.4673 - val_accuracy: 0.7778
# Epoch 19/50
# 24/24 [==============================] - 30s 1s/step - loss: 0.4604 - accuracy: 0.8087 - val_loss: 0.4623 - val_accuracy: 0.7889
# Epoch 20/50
# 24/24 [==============================] - 30s 1s/step - loss: 0.4420 - accuracy: 0.8156 - val_loss: 0.4946 - val_accuracy: 0.7722
# Epoch 21/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.4366 - accuracy: 0.8128 - val_loss: 0.6222 - val_accuracy: 0.7694
# Epoch 22/50
# 24/24 [==============================] - 30s 1s/step - loss: 0.4278 - accuracy: 0.8177 - val_loss: 0.4568 - val_accuracy: 0.7806
# Epoch 23/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.4253 - accuracy: 0.8156 - val_loss: 0.4884 - val_accuracy: 0.7722
# Epoch 24/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.3933 - accuracy: 0.8174 - val_loss: 0.4868 - val_accuracy: 0.7639
# Epoch 25/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.4026 - accuracy: 0.8253 - val_loss: 0.5092 - val_accuracy: 0.7778
# Epoch 26/50
# 24/24 [==============================] - 30s 1s/step - loss: 0.3837 - accuracy: 0.8358 - val_loss: 0.5856 - val_accuracy: 0.7639
# Epoch 27/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.3724 - accuracy: 0.8389 - val_loss: 0.5436 - val_accuracy: 0.7778
# Epoch 28/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.3412 - accuracy: 0.8486 - val_loss: 0.5729 - val_accuracy: 0.7611
# Epoch 29/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.3638 - accuracy: 0.8392 - val_loss: 0.5470 - val_accuracy: 0.7833
# Epoch 30/50
# 24/24 [==============================] - 28s 1s/step - loss: 0.3469 - accuracy: 0.8458 - val_loss: 1.6714 - val_accuracy: 0.6222
# Epoch 31/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.3858 - accuracy: 0.8462 - val_loss: 0.7365 - val_accuracy: 0.7722
# Epoch 32/50
# 24/24 [==============================] - 30s 1s/step - loss: 0.2863 - accuracy: 0.8656 - val_loss: 0.7045 - val_accuracy: 0.7611
# Epoch 33/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.2961 - accuracy: 0.8660 - val_loss: 0.6126 - val_accuracy: 0.7889
# Epoch 34/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.2789 - accuracy: 0.8736 - val_loss: 0.5637 - val_accuracy: 0.7750
# Epoch 35/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.3055 - accuracy: 0.8618 - val_loss: 0.5521 - val_accuracy: 0.7778
# Epoch 36/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.2510 - accuracy: 0.8806 - val_loss: 0.8217 - val_accuracy: 0.7778
# Epoch 37/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.2842 - accuracy: 0.8795 - val_loss: 0.6311 - val_accuracy: 0.7639
# Epoch 38/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.2494 - accuracy: 0.8878 - val_loss: 0.7331 - val_accuracy: 0.7444
# Epoch 39/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.2540 - accuracy: 0.8872 - val_loss: 0.7101 - val_accuracy: 0.7639
# Epoch 40/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.2293 - accuracy: 0.8899 - val_loss: 0.6928 - val_accuracy: 0.7528
# Epoch 41/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.2269 - accuracy: 0.9024 - val_loss: 0.9784 - val_accuracy: 0.7472
# Epoch 42/50
# 24/24 [==============================] - 28s 1s/step - loss: 0.2398 - accuracy: 0.8910 - val_loss: 1.1268 - val_accuracy: 0.6806
# Epoch 43/50
# 24/24 [==============================] - 30s 1s/step - loss: 0.2145 - accuracy: 0.9038 - val_loss: 0.7068 - val_accuracy: 0.7444
# Epoch 44/50
# 24/24 [==============================] - 30s 1s/step - loss: 0.2194 - accuracy: 0.9069 - val_loss: 0.9091 - val_accuracy: 0.7528
# Epoch 45/50
# 24/24 [==============================] - 30s 1s/step - loss: 0.1731 - accuracy: 0.9177 - val_loss: 0.9816 - val_accuracy: 0.7306
# Epoch 46/50
# 24/24 [==============================] - 28s 1s/step - loss: 0.4672 - accuracy: 0.8701 - val_loss: 1.0255 - val_accuracy: 0.7611
# Epoch 47/50
# 24/24 [==============================] - 28s 1s/step - loss: 0.1823 - accuracy: 0.9167 - val_loss: 1.1562 - val_accuracy: 0.7500
# Epoch 48/50
# 24/24 [==============================] - 30s 1s/step - loss: 0.2002 - accuracy: 0.9194 - val_loss: 0.8320 - val_accuracy: 0.7528
# Epoch 49/50
# 24/24 [==============================] - 31s 1s/step - loss: 0.1606 - accuracy: 0.9267 - val_loss: 1.1457 - val_accuracy: 0.7417
# Epoch 50/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.2624 - accuracy: 0.8986 - val_loss: 0.9573 - val_accuracy: 0.7583

# %% [markdown]
# #### testing the model

# %%
test_steps = int(len(df_test)/batch_size)

metrics = unfrozen_vgg19_model.evaluate(test_dataset,
                   steps = test_steps)
print("model accuracy:",metrics[1])
# Out:
# 3/3 [==============================] - 2s 582ms/step - loss: 1.3129 - accuracy: 0.7194
# model accuracy: 0.71944445

# %% [markdown]
# #### plotting training

# %%
plot_hist(unfrozen_vgg19_history, 'unfrozen_vgg19_rmsprop')

# %% [markdown]
# #### saving the history of the fitting

# %%
with open(cwd + '/trainHistoryDict/unfrozen_vgg19_rmsprop_history.p', 'wb') as file_pi:
        pickle.dump(unfrozen_vgg19_history.history, file_pi)
print('history saved')
# Out:
# history saved
